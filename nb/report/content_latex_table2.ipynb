# %% [markdown]
# # Content for Latex table

# %%
import pandas as pd
import geopandas as gpd
import os

# %%
csv_file = r"E:\cdu\data\compiled_data\tile_season_agb_si_zonal_stats.csv"

# %%
#dir_ = r"E:\cdu\data\roshna_data_20221019"
#dir_ = r"E:\cdu\data\slats\varified_by_rm"
output_dir = r"E:\cdu\data\output"

# %%
#excel_ = os.path.join(dir_, "slats_biomass_field_data_script.xlsx")

# %%
df = pd.read_csv(csv_file)
df
# Out:
#      uid        site      date   lon_gda94  lat_gda94  bio_l_kg1ha  \
# 0    125       nt001  20110523  131.209577 -13.945196     0.000000
# 1     42   barkely01  20111025  135.040695 -18.001762     0.000000
# 2     43   barkely02  20111026  135.259768 -18.056963     0.000000
# 3     45   barkely04  20111026  135.225612 -17.984787     0.000000
# 4     44   barkely03  20111026  135.288375 -18.024510     0.000000
# ..   ...         ...       ...         ...        ...          ...
# 160   29  NTADAC0002  20160506  132.340300 -12.739220    59.914556
# 161    1  NTAARP0001  20160602  132.270100 -13.557290    45.895500
# 162    7  NTAARP0002  20160602  132.294400 -13.545610    39.096167
# 163   16  NTAARP0003  20160603  132.457100 -13.516970    32.782500
# 164    3      buff01  20210713  130.898593 -12.336187   343.637143
#
#      bio_t_kg1ha  bio_b_kg1ha  bio_w_kg1ha  bio_br_kg1ha  ...      NDGIt  \
# 0       0.000000     0.000000       0.0000      0.000000  ...   -88149.0
# ...

# %%
print(list(df.columns))
# Out:
# ['uid', 'site', 'date', 'lon_gda94', 'lat_gda94', 'bio_l_kg1ha', 'bio_t_kg1ha', 'bio_b_kg1ha', 'bio_w_kg1ha', 'bio_br_kg1ha', 'bio_s_kg1ha', 'bio_r_kg1ha', 'bio_agb_kg1ha', 'c_l_kg1ha', 'c_t_kg1ha', 'c_b_kg1ha', 'c_w_kg1ha', 'c_br_kg1ha', 'c_s_kg1ha', 'c_r_kg1ha', 'c_agb_kg1ha', 'b1_dja_min', 'b1_dja_max', 'b1_dja_mean', 'b1_dja_med', 'b1_dja_std', 'b1_dja_p25', 'b1_dja_p50', 'b1_dja_p75', 'b1_dja_p95', 'b1_dja_p99', 'b1_dbi_min', 'b1_dbi_max', 'b1_dbi_mean', 'b1_dbi_med', 'b1_dbi_std', 'b1_dbi_p25', 'b1_dbi_p50', 'b1_dbi_p75', 'b1_dbi_p95', 'b1_dbi_p99', 'b2_dbi_min', 'b2_dbi_max', 'b2_dbi_mean', 'b2_dbi_med', 'b2_dbi_std', 'b2_dbi_p25', 'b2_dbi_p50', 'b2_dbi_p75', 'b2_dbi_p95', 'b2_dbi_p99', 'b3_dbi_min', 'b3_dbi_max', 'b3_dbi_mean', 'b3_dbi_med', 'b3_dbi_std', 'b3_dbi_p25', 'b3_dbi_p50', 'b3_dbi_p75', 'b3_dbi_p95', 'b3_dbi_p99', 'b4_dbi_min', 'b4_dbi_max', 'b4_dbi_mean', 'b4_dbi_med', 'b4_dbi_std', 'b4_dbi_p25', 'b4_dbi_p50', 'b4_dbi_p75', 'b4_dbi_p95', 'b4_dbi_p99', 'b5_dbi_min',
# ...

# %%
df1 = df[['site', 'date', 'lon_gda94', 'lat_gda94', 'bio_agb_kg1ha', 'stc_min', 'stc_max', 'stc_mean', 'stc_med']]

# %%
df1
# Out:
#            site      date   lon_gda94  lat_gda94  bio_agb_kg1ha  stc_min  \
# 0         nt001  20110523  131.209577 -13.945196       0.000000      2.0
# 1     barkely01  20111025  135.040695 -18.001762       0.000000      1.0
# 2     barkely02  20111026  135.259768 -18.056963       0.000000      1.0
# 3     barkely04  20111026  135.225612 -17.984787       0.000000      1.0
# 4     barkely03  20111026  135.288375 -18.024510       0.000000      1.0
# ..          ...       ...         ...        ...            ...      ...
# 160  NTADAC0002  20160506  132.340300 -12.739220     978.739611      8.0
# 161  NTAARP0001  20160602  132.270100 -13.557290    1358.280000      8.0
# 162  NTAARP0002  20160602  132.294400 -13.545610    1157.053333      3.0
# 163  NTAARP0003  20160603  132.457100 -13.516970     970.200000      3.0
# 164      buff01  20210713  130.898593 -12.336187    9995.510000      NaN
#
#      stc_max  stc_mean  stc_med
# 0       12.0    6.7500      7.0
# ...

# %%
name_list = df.site.tolist()

# %%
sorted(name_list)
# Out:
# ['NTAARP0001',
#  'NTAARP0002',
#  'NTAARP0003',
#  'NTADAC0001',
#  'NTADAC0002',
#  'NTAGFU0001',
#  'NTAGFU0002',
#  'NTAGFU0003',
#  'NTAGFU0004',
#  'NTAGFU0005',
#  'NTAGFU0006',
#  'NTAGFU0007',
#  'NTAGFU0008',
#  'NTAGFU0009',
#  'NTAGFU0010',
#  'NTAGFU0011',
#  'NTAGFU0012',
#  'NTAGFU0013',
#  'NTAGFU0014',
#  'NTAGFU0015',
#  'NTAGFU0016',
#  'NTAGFU0017',
#  'NTAGFU0018',
#  'NTAGFU0019',
#  'NTAGFU0020',
#  'NTAGFU0021',
#  'NTAGFU0022',
#  'NTAGFU0023',
#  'NTAGFU0024',
#  'NTAGFU0025',
#  'NTAGFU0026',
#  'NTAGFU0027',
#  'NTAGFU0028',
#  'NTAGFU0029',
#  'NTAGFU0030',
#  'NTAGFU0031',
#  'NTAGFU0032',
#  'NTAGFU0033',
#  'NTAGFU0034',
#  'NTAGFU0035',
#  'NTAGFU0036',
#  'NTAGFU0037',
#  'NTAGFU0038',
#  'NTAGFU0039',
#  'NTAGFU0040',
#  'NTAGFU0041',
#  'NTAMGD0001',
#  'NTAMGD0002',
#  'NTAMGD0003',
#  'NTAMGD0004',
#  'NTAMGD0005',
#  'NTAPCK0001',
#  'NTAPCK0002',
#  'NTASTU0001',
#  'NTASTU0002',
#  'NTASTU0003',
#  'NTASTU0004',
#  'NTASTU0005',
# ...

# %%
for i in sorted(name_list):
    print(i, "& & & \\\\")
# Out:
# agb02 & & & \\
# amg01 & & & \\
# amg02 & & & \\
# amg03 & & & \\
# amg05 & & & \\
# amg06 & & & \\
# amg08 & & & \\
# amg09 & & & \\
# amg10 & & & \\
# ant01 & & & \\
# ant02 & & & \\
# ant03 & & & \\
# ant04 & & & \\
# ant05 & & & \\
# ant06 & & & \\
# ant07 & & & \\
# ant09 & & & \\
# antgr01 & & & \\
# auv01 & & & \\
# auv02 & & & \\
# auv03 & & & \\
# auv04 & & & \\
# auv05 & & & \\
# auv06 & & & \\
# auv07 & & & \\
# auv08 & & & \\
# auv08 & & & \\
# barkely01 & & & \\
# barkely02 & & & \\
# barkely03 & & & \\
# barkely04 & & & \\
# barkely05 & & & \\
# barkely06 & & & \\
# barkely07 & & & \\
# buff01 & & & \\
# centa13 & & & \\
# centa14 & & & \\
# el01 & & & \\
# el02 & & & \\
# ep01 & & & \\
# girra01 & & & \\
# girra02 & & & \\
# gulf10 & & & \\
# gulf11 & & & \\
# gulf12 & & & \\
# hsf01 & & & \\
# hsf02 & & & \\
# hshr01 & & & \\
# jdr01 & & & \\
# jdr02 & & & \\
# jdr03 & & & \\
# jdr04 & & & \\
# jdr05 & & & \\
# larr15 & & & \\
# legu01 & & & \\
# legu02 & & & \\
# ...
