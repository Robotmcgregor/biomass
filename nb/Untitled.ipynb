# %% [markdown]
# # tern_biomass_clean

# %%
import pandas as pd
from glob import glob
import os
from calendar import monthrange
from datetime import datetime

# %%
locations = pd.read_excel(r"F:\cdu\data\tern_data\Copy of TERN basal_area_data_Grant_SEPT2022.xlsx", sheet_name="Site locations_NT north")

# %%
basal = pd.read_excel(r"F:\cdu\data\tern_data\Copy of TERN basal_area_data_Grant_SEPT2022.xlsx", sheet_name="NT north bioregions_spp")

# %%
locations
# Out:
#       siteName  siteVisitName siteType    siteVisitStartDate  \
# 0   NTAARP0001       20160602     site  2016-06-02T08:52:59Z
# 1   NTAARP0002       20160602     site  2016-06-02T17:24:35Z
# 2   NTAARP0003       20160603     site  2016-06-03T14:50:55Z
# 3   NTADAC0001       20130528     site  2013-05-28T00:00:00Z
# 4   NTADAC0002       20160506     site  2016-05-06T09:17:06Z
# ..         ...            ...      ...                   ...
# 58  NTTDAB0001       20140317     site  2014-03-17T00:00:00Z
# 59  NTTDAC0001       20140318     site  2014-03-18T00:00:00Z
# 60  NTTMGD0001       20140315     site  2014-03-15T00:00:00Z
# 61  NTTPCK0001       20140319     site  2014-03-19T00:00:00Z
# 62  NTTSTU0001       20140315     site  2014-03-15T00:00:00Z
#
#                                      site.description  latitude  longitude  \
# 0   Kakadu National Park, 37km west of Gimbit home... -13.55729   132.2701
# 1   Kakadu National Park, 34.5km west of Gimbit ho... -13.54561   132.2944
# ...

# %%
basal
# Out:
#           site_unique   site_name  site_visitid            standardised_name  \
# 0    NTAARP0001-58422  NTAARP0001         58422                Acacia mimula
# 1    NTAARP0001-58422  NTAARP0001         58422           Buchanania obovata
# 2    NTAARP0001-58422  NTAARP0001         58422  Erythrophleum chlorostachys
# 3    NTAARP0001-58422  NTAARP0001         58422        Eucalyptus tetrodonta
# 4    NTAARP0001-58422  NTAARP0001         58422             Owenia vernicosa
# ..                ...         ...           ...                          ...
# 294  NTTSTU0001-53585  NTTSTU0001         53585        Gyrocarpus americanus
# 295  NTTSTU0001-53585  NTTSTU0001         53585    Macropteranthes kekwickii
# 296  NTTSTU0001-53585  NTTSTU0001         53585        Melaleuca viridiflora
# 297  NTTSTU0001-53585  NTTSTU0001         53585         Terminalia canescens
# 298  NTTSTU0001-53585  NTTSTU0001         53585          Terminalia volucris
#
#      basal_area_m2_ha
# ...
