# %% [markdown]
# # Colate SI Zonal Seasonal and SD Tiles

# %% [markdown]
# #### Import modules

# %%
import pandas as pd
import os

# due to the size of dataset
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# #### Inputs

# %%
tile_path = r"D:\cdu\data\zonal_stats\output\dbg_dp0_dp1_dry_dp1_annual_indices_clean.csv"
season_path = r"D:\cdu\data\zonal_stats\output\dja_dbi_dim_dis_dka_stc_h99a2_fpca2_dry_indicies_clean.csv"

# %% [markdown]
# #### Outputs

# %%
output_ = r"D:\cdu\data\compiled_data"

# df_si.to_csv(r'E:\cdu\data\zonal_stats\output\dbg_dp0_df_dp1_dry_dp1_annual_indices_clean.csv', index=False)

# %%
tile = pd.read_csv(tile_path)
season = pd.read_csv(season_path)

# %%
tile.shape
# Out:
# (165, 125)

# %%
print(list(tile))
# Out:
# ['uid', 'site', 'date', 'lon_gda94', 'lat_gda94', 'bio_l_kg1ha', 'bio_t_kg1ha', 'bio_b_kg1ha', 'bio_w_kg1ha', 'bio_br_kg1ha', 'bio_s_kg1ha', 'bio_r_kg1ha', 'bio_agb_kg1ha', 'c_l_kg1ha', 'c_t_kg1ha', 'c_b_kg1ha', 'c_w_kg1ha', 'c_br_kg1ha', 'c_s_kg1ha', 'c_r_kg1ha', 'c_agb_kg1ha', 'basal_dt', 'uid_', 'image', 'year', 'month', 'day', 'b1_dbg_count', 'b1_dbg_min', 'b1_dbg_max', 'b1_dbg_mean', 'b1_dbg_med', 'b1_dbg_std', 'b1_dbg_p25', 'b1_dbg_p50', 'b1_dbg_p75', 'b1_dbg_p95', 'b1_dbg_p99', 'b1_dbg_range', 'b2_dbg_count', 'b2_dbg_min', 'b2_dbg_max', 'b2_dbg_mean', 'b2_dbg_med', 'b2_dbg_std', 'b2_dbg_p25', 'b2_dbg_p50', 'b2_dbg_p75', 'b2_dbg_p95', 'b2_dbg_p99', 'b2_dbg_range', 'b3_dbg_count', 'b3_dbg_min', 'b3_dbg_max', 'b3_dbg_mean', 'b3_dbg_med', 'b3_dbg_std', 'b3_dbg_p25', 'b3_dbg_p50', 'b3_dbg_p75', 'b3_dbg_p95', 'b3_dbg_p99', 'b3_dbg_range', 'b4_dbg_count', 'b4_dbg_min', 'b4_dbg_max', 'b4_dbg_mean', 'b4_dbg_med', 'b4_dbg_std', 'b4_dbg_p25', 'b4_dbg_p50', 'b4_dbg_p75', 'b4_dbg_p95', 'b4
# ...

# %%
season.shape
# Out:
# (165, 185)

# %%
print(list(season))
# Out:
# ['uid', 'site', 'date', 'lon_gda94', 'lat_gda94', 'bio_l_kg1ha', 'bio_t_kg1ha', 'bio_b_kg1ha', 'bio_w_kg1ha', 'bio_br_kg1ha', 'bio_s_kg1ha', 'bio_r_kg1ha', 'bio_agb_kg1ha', 'c_l_kg1ha', 'c_t_kg1ha', 'c_b_kg1ha', 'c_w_kg1ha', 'c_br_kg1ha', 'c_s_kg1ha', 'c_r_kg1ha', 'c_agb_kg1ha', 'b1_dja_min', 'b1_dja_max', 'b1_dja_mean', 'b1_dja_med', 'b1_dja_std', 'b1_dja_p25', 'b1_dja_p50', 'b1_dja_p75', 'b1_dja_p95', 'b1_dja_p99', 'b1_dbi_min', 'b1_dbi_max', 'b1_dbi_mean', 'b1_dbi_med', 'b1_dbi_std', 'b1_dbi_p25', 'b1_dbi_p50', 'b1_dbi_p75', 'b1_dbi_p95', 'b1_dbi_p99', 'b2_dbi_min', 'b2_dbi_max', 'b2_dbi_mean', 'b2_dbi_med', 'b2_dbi_std', 'b2_dbi_p25', 'b2_dbi_p50', 'b2_dbi_p75', 'b2_dbi_p95', 'b2_dbi_p99', 'b3_dbi_min', 'b3_dbi_max', 'b3_dbi_mean', 'b3_dbi_med', 'b3_dbi_std', 'b3_dbi_p25', 'b3_dbi_p50', 'b3_dbi_p75', 'b3_dbi_p95', 'b3_dbi_p99', 'b4_dbi_min', 'b4_dbi_max', 'b4_dbi_mean', 'b4_dbi_med', 'b4_dbi_std', 'b4_dbi_p25', 'b4_dbi_p50', 'b4_dbi_p75', 'b4_dbi_p95', 'b4_dbi_p99', 'b5_dbi_min',
# ...

# %%
df = pd.merge(season, tile,  how='left', left_on=['site', 'uid', 'date', 'lon_gda94', 'lat_gda94', 'bio_l_kg1ha', 'bio_t_kg1ha',
                  'bio_b_kg1ha', 'bio_w_kg1ha', 'bio_br_kg1ha', 'bio_s_kg1ha', 'bio_r_kg1ha', 'bio_agb_kg1ha', 'c_l_kg1ha',
                  'c_t_kg1ha', 'c_b_kg1ha', 'c_w_kg1ha', 'c_br_kg1ha', 'c_s_kg1ha', 'c_r_kg1ha', 'c_agb_kg1ha'],
                  right_on = ['site', 'uid', 'date', 'lon_gda94', 'lat_gda94', 'bio_l_kg1ha', 'bio_t_kg1ha',
                  'bio_b_kg1ha', 'bio_w_kg1ha', 'bio_br_kg1ha', 'bio_s_kg1ha', 'bio_r_kg1ha', 'bio_agb_kg1ha', 'c_l_kg1ha',
                  'c_t_kg1ha', 'c_b_kg1ha', 'c_w_kg1ha', 'c_br_kg1ha', 'c_s_kg1ha', 'c_r_kg1ha', 'c_agb_kg1ha'])

# %%
#df = pd.concat([tile, season])

# %%
df.shape
# Out:
# (165, 289)

# %%
df.sample(10)
# Out:
#      uid        site      date   lon_gda94  lat_gda94    bio_l_kg1ha  \
# 58    32       amg10  20120622  134.187689 -16.415578     110.517143
# 5     48   barkely07  20111027  135.609310 -18.085316      64.003929
# 8     34  NTAGFU0001  20120412  137.069300 -18.905510      10.927500
# 146  253  NTTDAB0001  20140317  131.674000 -13.962880      15.894545
# 150  206  NTAMGD0005  20160429  133.483600 -17.455850      30.597000
# 64    38       ant06  20120625  135.152522 -18.266308     202.939286
# 55    27       amg03  20120620  134.031626 -16.778991       0.000000
# 99    82       vrd26  20120730  131.217687 -16.651065       0.000000
# 163   16  NTAARP0003  20160603  132.457100 -13.516970      32.782500
# 151  205  NTAMGD0004  20160429  133.523500 -17.521320  437056.290000
#
#        bio_t_kg1ha   bio_b_kg1ha   bio_w_kg1ha  bio_br_kg1ha   bio_s_kg1ha  \
# 58      120.036000  4.187960e+02  1.304100e+03  9.939160e+02  1.722896e+03
# ...

# %%
print(list(df))
# Out:
# ['uid', 'site', 'date', 'lon_gda94', 'lat_gda94', 'bio_l_kg1ha', 'bio_t_kg1ha', 'bio_b_kg1ha', 'bio_w_kg1ha', 'bio_br_kg1ha', 'bio_s_kg1ha', 'bio_r_kg1ha', 'bio_agb_kg1ha', 'c_l_kg1ha', 'c_t_kg1ha', 'c_b_kg1ha', 'c_w_kg1ha', 'c_br_kg1ha', 'c_s_kg1ha', 'c_r_kg1ha', 'c_agb_kg1ha', 'b1_dja_min', 'b1_dja_max', 'b1_dja_mean', 'b1_dja_med', 'b1_dja_std', 'b1_dja_p25', 'b1_dja_p50', 'b1_dja_p75', 'b1_dja_p95', 'b1_dja_p99', 'b1_dbi_min', 'b1_dbi_max', 'b1_dbi_mean', 'b1_dbi_med', 'b1_dbi_std', 'b1_dbi_p25', 'b1_dbi_p50', 'b1_dbi_p75', 'b1_dbi_p95', 'b1_dbi_p99', 'b2_dbi_min', 'b2_dbi_max', 'b2_dbi_mean', 'b2_dbi_med', 'b2_dbi_std', 'b2_dbi_p25', 'b2_dbi_p50', 'b2_dbi_p75', 'b2_dbi_p95', 'b2_dbi_p99', 'b3_dbi_min', 'b3_dbi_max', 'b3_dbi_mean', 'b3_dbi_med', 'b3_dbi_std', 'b3_dbi_p25', 'b3_dbi_p50', 'b3_dbi_p75', 'b3_dbi_p95', 'b3_dbi_p99', 'b4_dbi_min', 'b4_dbi_max', 'b4_dbi_mean', 'b4_dbi_med', 'b4_dbi_std', 'b4_dbi_p25', 'b4_dbi_p50', 'b4_dbi_p75', 'b4_dbi_p95', 'b4_dbi_p99', 'b5_dbi_min',
# ...

# %%
df1 = df.dropna()

# %%
df2 = df1[['bio_agb_kg1ha', 'b3_dbi_mean', 'h99a2_p50', 'fpca2_min', 'ratio32m', 'GSAVIa', 'GNDVIa', 'CVIa', 'NDGIa', 'RIa', 'NBRa', 'NDIIa', 'GDVIa', 'MSAVIa', 'DVIa', 'SAVIa', 'NDVIa', 'MSRa']]

# %%
df2.describe().transpose()
# Out:
#                count          mean           std           min           25%  \
# bio_agb_kg1ha  138.0  3.786244e+05  2.177274e+06  0.000000e+00  0.000000e+00
# b3_dbi_mean    138.0  1.119930e+03  4.590656e+02  2.506875e+02  7.500625e+02
# h99a2_p50      138.0  9.816406e+00  4.389284e+00  1.166214e+00  6.604369e+00
# fpca2_min      138.0  6.942330e+00  8.312212e+00  8.696318e-03  1.212895e+00
# ratio32m       138.0  1.424266e+07  1.577714e+06  6.628656e+06  1.348734e+07
# GSAVIa         138.0  2.462408e+06  7.618855e+05  5.813560e+05  2.190153e+06
# GNDVIa         138.0  4.826085e+06  1.271234e+06  1.893266e+06  3.832656e+06
# CVIa           138.0  4.195083e+07  1.432217e+07  1.828107e+07  3.247752e+07
# NDGIa          138.0 -1.499282e+06  7.480031e+05 -3.057410e+06 -1.954846e+06
# RIa            138.0  1.499282e+06  7.480031e+05 -1.290780e+06  1.195364e+06
# NBRa           138.0  9.140635e+05  2.729529e+06 -5.674381e+06  1.237360e+05
# ...

# %%
df3 = df2[df2['bio_agb_kg1ha']>=0]

# %%
df3.to_csv(os.path.join(output_, "test_ml_clean.csv"), index = False)

# %%
df.to_csv(os.path.join(output_, "tile_season_agb_si_zonal_stats.csv"), index = False)

# %%
print("exported: ", os.path.join(output_, "tile_season_agb_si_zonal_stats.csv"))
# Out:
# exported:  E:\cdu\data\compiled_data\tile_season_agb_si_zonal_stats.csv
