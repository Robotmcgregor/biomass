# %%
import pandas as pd
import numpy as np

# Sample data
data = {
    'A': [1, 2, np.nan, 4],
    'B': [np.nan, 2, np.nan, 4],
    'C': [1, np.nan, np.nan, 4],
    'D': [1, 2, 3, 4]
}

df = pd.DataFrame(data)

# Display original DataFrame
print("Original DataFrame:")
print(df)

# Drop rows where both columns 'A' and 'B' have null values
df_dropped = df.dropna(subset=['A', 'B'], how='all')

# Display the DataFrame after dropping rows
print("\nDataFrame after dropping rows where both 'A' and 'B' are null:")
print(df_dropped)
# Out:
# Original DataFrame:
#      A    B    C  D
# 0  1.0  NaN  1.0  1
# 1  2.0  2.0  NaN  2
# 2  NaN  NaN  NaN  3
# 3  4.0  4.0  4.0  4
#
# DataFrame after dropping rows where both 'A' and 'B' are null:
#      A    B    C  D
# 0  1.0  NaN  1.0  1
# 1  2.0  2.0  NaN  2
# 3  4.0  4.0  4.0  4

# %%
dp1_file = r"C:\Users\robot\projects\outputs\biomass_collation\ot_collation_tile_data_20240710_1101\sr_fc_zonal_stats\tile_concat\dp1_zonal_concat.csv"
dp1 = pd.read_csv(dp1_file)
dp1
# Out:
#        uid                 site  \
# 0        1  ntagfu0010.2012_1ha
# 1        1  ntagfu0010.2012_1ha
# 2        1  ntagfu0010.2012_1ha
# 3        1  ntagfu0010.2012_1ha
# 4        1  ntagfu0010.2012_1ha
# ...    ...                  ...
# 13842   16      legu08.2012_1ha
# 13843   16      legu08.2012_1ha
# 13844   16      legu08.2012_1ha
# 13845   16      legu08.2012_1ha
# 13846   16      legu08.2012_1ha
#
#                                                   image  s_day  s_month  \
# 0      lztmre_p101r072_m198801198812_dp1m3_dkbsmask.img      1        1
# 1      lztmre_p101r072_m198901198912_dp1m3_dkbsmask.img      1        1
# 2      lztmre_p101r072_m199001199012_dp1m3_dkbsmask.img      1        1
# 3      lztmre_p101r072_m199101199112_dp1m3_dkbsmask.img      1        1
# 4      lztmre_p101r072_m199201199212_dp1m3_dkbsmask.img      1        1
# ...                                                 ...    ...      ...
# ...
