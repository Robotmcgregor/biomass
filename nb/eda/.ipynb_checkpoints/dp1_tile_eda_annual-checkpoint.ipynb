# %%
# import modules
import pandas as pd
import numpy as np
import scipy.stats as scistat
import statsmodels.api as sm

# visualisation
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# load data
csv_file = r"F:\cdu\data\zonal_stats\output\merged_slats_field_agb_dp1_annual.csv"

# %%
df = pd.read_csv(csv_file, parse_dates=['date'])
# set uid to index
df.set_index("uid_x", inplace=True)
df.shape
# Out:
# (180, 69)

# %%
df.columns
# Out:
# Index(['site', 'date', 'lon_gda94', 'lat_gda94', 'bio_l_kg1ha', 'bio_t_kg1ha',
#        'bio_b_kg1ha', 'bio_w_kg1ha', 'bio_br_kg1ha', 'bio_s_kg1ha',
#        'bio_r_kg1ha', 'bio_agb_kg1ha', 'c_l_kg1ha', 'c_t_kg1ha', 'c_b_kg1ha',
#        'c_w_kg1ha', 'c_br_kg1ha', 'c_s_kg1ha', 'c_r_kg1ha', 'c_agb_kg1ha',
#        'basal_dt', 'uid_y', 'image', 's_day', 's_month', 's_year', 's_date',
#        'e_day', 'e_month', 'e_year', 'e_date', 'b1_dp1_min', 'b1_dp1_max',
#        'b1_dp1_mean', 'b1_dp1_count', 'b1_dp1_std', 'b1_dp1_med', 'b1_dp1_p25',
#        'b1_dp1_p50', 'b1_dp1_p75', 'b1_dp1_p95', 'b1_dp1_p99', 'b1_dp1_range',
#        'b2_dp1_min', 'b2_dp1_max', 'b2_dp1_mean', 'b2_dp1_count', 'b2_dp1_std',
#        'b2_dp1_med', 'b2_dp1_p25', 'b2_dp1_p50', 'b2_dp1_p75', 'b2_dp1_p95',
#        'b2_dp1_p99', 'b2_dp1_range', 'b3_dp1_min', 'b3_dp1_max', 'b3_dp1_mean',
#        'b3_dp1_count', 'b3_dp1_med', 'b3_dp1_p25', 'b3_dp1_p50', 'b3_dp1_p75',
#        'b3_dp1_p95', 'b3_dp1_p99', 'b3_dp1_range', 'b3_dp1_std', 'image_s_dt',
#        'image_e_dt'],
#       dtype='object')

# %%
# drop unwanted columns
df.drop(['date', 'lon_gda94', 'lat_gda94', 'bio_l_kg1ha', 'bio_t_kg1ha', 'bio_b_kg1ha', 'bio_w_kg1ha', 'bio_br_kg1ha', 
         'bio_s_kg1ha', 'bio_r_kg1ha', 'c_l_kg1ha', 'c_t_kg1ha', 'c_b_kg1ha', 'c_w_kg1ha', 'c_br_kg1ha', 'c_s_kg1ha', 
         'c_r_kg1ha', 'c_agb_kg1ha', 'basal_dt', 'uid_y', 'image', 's_day', 's_month', 's_year', 's_date',
       'e_day', 'e_month', 'e_year', 'e_date', 'b1_dp1_count', 'b2_dp1_count', 'b3_dp1_count',
        'b1_dp1_range', 'b2_dp1_range', 'b3_dp1_range','image_s_dt',
       'image_e_dt'], axis=1, inplace=True)

# %%
#drop null values
df.dropna(inplace=True)

# %%
df.index.nunique()
# Out:
# 67

# %%
df.sample(8, random_state=2).T
# Out:
# uid_x              55        1           143       20          144  \
# site           girra01     lit01  NTAGFU0021     nt004  NTAGFU0022
# bio_agb_kg1ha  17994.8   25585.1     1700.16         0     1956.57
# b1_dp1_min           9         1           5        24           4
# b1_dp1_max          28         2           9        27          28
# b1_dp1_mean    14.3333   1.33333     7.44444   26.1111     17.5556
# b1_dp1_std     6.58281  0.471405     1.34256  0.993808      8.9952
# b1_dp1_med          10         1           8        26          24
# b1_dp1_p25          10         1           6        26           9
# b1_dp1_p50          10         1           8        26          24
# b1_dp1_p75          18         2           8        27          25
# b1_dp1_p95          26         2           9        27        26.8
# b1_dp1_p99        27.6         2           9        27       27.76
# b2_dp1_min          24        62           7        28           5
# b2_dp1_max          55        72          22        35          17
# b2_dp1_mean    45.2222   67.4167     11.5556   31.6667     7.88889
# b2_dp1_std     11.1831    2.8419        4.45   2.21108     3.44624
# b2_dp1_med          51        68          11        32           6
# b2_dp1_p25          49     65.75           9        30           6
# b2_dp1_p50          51        68          11        32           6
# b2_dp1_p75          51        69          13        34           8
# b2_dp1_p95        53.4     71.45        19.2      34.6        13.8
# b2_dp1_p99       54.68     71.89       21.44     34.92       16.36
# b3_dp1_min          32        26          69        38          64
# b3_dp1_max          51        36          84        44          83
# b3_dp1_mean         39   29.6667     79.6667   40.6667     72.8889
# b3_dp1_med          38      28.5          80        40          68
# b3_dp1_p25          37        28          79        39          67
# b3_dp1_p50          38      28.5          80        40          68
# b3_dp1_p75          38      30.5          83        42          81
# b3_dp1_p95          49      34.9          84      43.2          83
# b3_dp1_p99        50.6     35.78          84     43.84          83
# b3_dp1_std     5.55778   2.83823     4.32049   1.82574     7.53428
#
# uid_x                  140      52         37
# site            NTAGFU0018    agb02  barkely01
# bio_agb_kg1ha  1.29347e+07        0          0
# b1_dp1_min               4        7          3
# b1_dp1_max              19       12         18
# b1_dp1_mean           9.75  9.77778    9.66667
# b1_dp1_std          4.2451  1.31468     5.2915
# b1_dp1_med             8.5       10          8
# b1_dp1_p25            6.75        9          6
# b1_dp1_p50             8.5       10          8
# b1_dp1_p75           13.25       10         15
# b1_dp1_p95           16.25     11.6       17.6
# b1_dp1_p99           18.45    11.92      17.92
# b2_dp1_min              14       43          3
# b2_dp1_max              38       50         18
# b2_dp1_mean        23.8333  46.6667    11.5556
# b2_dp1_std         7.66848  2.21108    4.57314
# b2_dp1_med            21.5       47         13
# b2_dp1_p25           17.75       46          9
# b2_dp1_p50            21.5       47         13
# b2_dp1_p75           29.75       48         15
# b2_dp1_p95           36.35     49.2       17.2
# b2_dp1_p99           37.67    49.84      17.84
# b3_dp1_min              46       39         65
# b3_dp1_max              77       49         86
# b3_dp1_mean        64.6667  42.1111    77.2222
# b3_dp1_med            70.5       41         81
# b3_dp1_p25            54.5       41         66
# b3_dp1_p50            70.5       41         81
# b3_dp1_p75              74       42         84
# b3_dp1_p95            75.9       47         86
# b3_dp1_p99           76.78     48.6         86
# b3_dp1_std         11.2867  2.76664    8.66382

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print (df.describe())
# Out:
#        bio_agb_kg1ha  b1_dp1_min  b1_dp1_max  b1_dp1_mean  b1_dp1_std  \
# count   6.700000e+01   67.000000   67.000000    67.000000   67.000000
# mean    1.547971e+06   10.552239   20.985075    15.385676    3.192746
# std     4.224587e+06   10.821252   14.431124    12.758484    2.200950
# min     0.000000e+00    1.000000    2.000000     1.333333    0.471405
# 25%     1.293600e+02    3.500000   10.000000     7.125000    1.565982
# 50%     1.164240e+03    8.000000   19.000000    11.583333    2.645751
# 75%     6.225707e+03   12.000000   28.500000    19.944444    3.875175
# max     1.293471e+07   55.000000   80.000000    69.416667    9.183318
#
#        b1_dp1_med  b1_dp1_p25  b1_dp1_p50  b1_dp1_p75  b1_dp1_p95  b1_dp1_p99  \
# count   67.000000   67.000000   67.000000   67.000000   67.000000   67.000000
# mean    15.231343   13.376866   15.231343   17.208955   20.050746   20.798209
# std     12.995141   12.699199   12.995141   13.407200   14.158849   14.369795
# min      1.000000    1.000000    1.000000    2.000000    2.000000    2.000000
# 25%      7.000000    5.875000    7.000000    7.875000    9.600000    9.920000
# 50%     11.000000    9.000000   11.000000   14.000000   16.400000   18.450000
# 75%     20.500000   17.500000   20.500000   23.500000   27.450000   28.270000
# max     70.000000   67.750000   70.000000   71.500000   77.800000   79.560000
#
#        b2_dp1_min  b2_dp1_max  b2_dp1_mean  b2_dp1_std  b2_dp1_med  \
# count   67.000000   67.000000    67.000000   67.000000    67.00000
# mean    22.462687   34.686567    28.414905    3.760401    28.41791
# std     18.660709   19.188229    19.368913    2.097385    19.77326
# min      1.000000    3.000000     1.777778    0.628539     2.00000
# 25%      7.000000   20.500000    13.791667    2.211083    13.50000
# 50%     19.000000   30.000000    23.833333    3.391165    24.00000
# 75%     32.500000   49.000000    43.763889    4.511567    44.00000
# max     84.000000   89.000000    87.500000   11.183100    88.00000
#
#        b2_dp1_p25  b2_dp1_p50  b2_dp1_p75  b2_dp1_p95  b2_dp1_p99  b3_dp1_min  \
# count   67.000000    67.00000   67.000000   67.000000   67.000000   67.000000
# mean    26.100746    28.41791   30.794776   33.535821   34.456418   48.000000
# std     19.640956    19.77326   19.788174   19.323110   19.206412   16.172367
# min      1.000000     2.00000    2.000000    2.600000    2.920000    7.000000
# 25%     10.875000    13.50000   16.125000   18.325000   20.335000   38.000000
# 50%     21.750000    24.00000   26.250000   28.900000   29.780000   47.000000
# 75%     41.875000    44.00000   46.000000   48.200000   48.880000   58.500000
# max     87.000000    88.00000   89.000000   89.000000   89.000000   83.000000
#
#        b3_dp1_max  b3_dp1_mean  b3_dp1_med  b3_dp1_p25  b3_dp1_p50  \
# count   67.000000    67.000000   67.000000   67.000000   67.000000
# mean    61.746269    54.743056   54.679104   51.992537   54.679104
# std     17.027022    17.152784   17.610625   17.227366   17.610625
# min     12.000000     9.333333    9.000000    8.000000    9.000000
# 25%     48.500000    42.000000   41.000000   39.500000   41.000000
# 50%     63.000000    53.666667   54.500000   52.000000   54.500000
# 75%     76.500000    67.472222   69.000000   64.500000   69.000000
# max     91.000000    87.777778   89.000000   88.000000   89.000000
#
#        b3_dp1_p75  b3_dp1_p95  b3_dp1_p99  b3_dp1_std
# count   67.000000   67.000000   67.000000   67.000000
# mean    57.402985   60.679104   61.532836    4.252007
# std     17.844390   17.343419   17.080681    2.187367
# min     10.250000   12.000000   12.000000    0.874890
# 25%     44.000000   47.425000   48.260000    2.520819
# 50%     58.000000   61.000000   62.890000    3.491060
# 75%     74.000000   75.750000   76.390000    5.765970
# max     91.000000   91.000000   91.000000   11.286669

# %%
key_var = ['bio_agb_kg1ha', 'b1_dp1_mean', 'b1_dp1_med', 'b2_dp1_mean', 'b2_dp1_med', 'b3_dp1_mean', 'b3_dp1_med']

# %%
df_key = df[key_var]

# %%
df_key
# Out:
#        bio_agb_kg1ha  b1_dp1_mean  b1_dp1_med  b2_dp1_mean  b2_dp1_med  \
# uid_x
# 37          0.000000     9.666667         8.0    11.555556        13.0
# 39          0.000000     6.111111         6.0     4.444444         4.0
# 38          0.000000    13.000000        14.0     4.222222         2.0
# 41          0.000000    18.888889        19.0     9.000000         8.0
# 40          0.000000     9.000000         7.0    16.222222        18.0
# ...              ...          ...         ...          ...         ...
# 169       989.555000     4.750000         4.5    52.416667        55.5
# 122       978.739611     8.000000         8.0    55.166667        56.0
# 118      1358.280000     2.555556         3.0    56.111111        56.0
# 119      1157.053333     4.444444         4.0    33.666667        35.0
# 120       970.200000    15.000000        14.0    40.750000        40.5
#
#        b3_dp1_mean  b3_dp1_med
# uid_x
# 37       77.222222        81.0
# 39       87.777778        89.0
# 38       81.666667        83.0
# 41       70.777778        72.0
# 40       73.555556        72.0
# ...            ...         ...
# 169      41.416667        39.0
# 122      35.000000        35.0
# 118      40.000000        40.0
# 119      60.111111        59.0
# 120      42.833333        41.5
#
# [67 rows x 7 columns]

# %%
df_key.describe()
# Out:
#        bio_agb_kg1ha  b1_dp1_mean  b1_dp1_med  b2_dp1_mean  b2_dp1_med  \
# count   6.700000e+01    67.000000   67.000000    67.000000    67.00000
# mean    1.547971e+06    15.385676   15.231343    28.414905    28.41791
# std     4.224587e+06    12.758484   12.995141    19.368913    19.77326
# min     0.000000e+00     1.333333    1.000000     1.777778     2.00000
# 25%     1.293600e+02     7.125000    7.000000    13.791667    13.50000
# 50%     1.164240e+03    11.583333   11.000000    23.833333    24.00000
# 75%     6.225707e+03    19.944444   20.500000    43.763889    44.00000
# max     1.293471e+07    69.416667   70.000000    87.500000    88.00000
#
#        b3_dp1_mean  b3_dp1_med
# count    67.000000   67.000000
# mean     54.743056   54.679104
# std      17.152784   17.610625
# min       9.333333    9.000000
# 25%      42.000000   41.000000
# 50%      53.666667   54.500000
# 75%      67.472222   69.000000
# max      87.777778   89.000000

# %% [markdown]
# Substantial differences between the mean and median, as an indication of skewness.

# %% [markdown]
# The interquartile range is also the target value, with the 75th percentile value being about 800 times larger than the 25th percentile value (9210.71, 18.48). We can compare that with the band median and means; b2 has the largest distribution and woyld likly be better at explaining the differences with the target vale; however, the 75th percentile value being about 5 times larger than the 25th percentile vale (55, 11).

# %%
df_key.quantile(np.arange(0.0, 1.1, 0.1))
# Out:
#      bio_agb_kg1ha  b1_dp1_mean  b1_dp1_med  b2_dp1_mean  b2_dp1_med  \
# 0.0   0.000000e+00     1.333333         1.0     1.777778         2.0
# 0.1   0.000000e+00     2.709722         2.8     6.766667         6.0
# 0.2   1.478400e+01     5.577778         6.0    11.022222        11.0
# 0.3   2.587200e+02     7.977778         7.9    14.733333        15.0
# 0.4   6.640480e+02     9.700000         9.0    20.166667        19.8
# 0.5   1.164240e+03    11.583333        11.0    23.833333        24.0
# 0.6   2.113188e+03    15.566667        14.8    30.200000        30.2
# 0.7   4.440167e+03    18.911111        19.2    38.251389        38.6
# 0.8   1.666343e+04    21.090278        22.3    45.211111        45.9
# 0.9   1.293471e+07    31.366667        30.8    53.516667        55.2
# 1.0   1.293471e+07    69.416667        70.0    87.500000        88.0
#
#      b3_dp1_mean  b3_dp1_med
# 0.0     9.333333         9.0
# 0.1    35.900000        34.8
# 0.2    40.133333        39.2
# 0.3    43.566667        42.9
# 0.4    48.708333        48.2
# 0.5    53.666667        54.5
# 0.6    59.133333        58.8
# 0.7    64.700000        65.0
# 0.8    72.466667        71.8
# 0.9    77.533333        79.0
# 1.0    87.777778        89.0

# %% [markdown]
# Normal distributions are distributed symmetrically (have low skew), and that they have relatively normal tails (neither excessively high nor excessively low kurtosis).

# %% [markdown]
# Expect a value near 0 for skew and 3 for kurtosis

# %%
df_key.skew()
# Out:
# bio_agb_kg1ha    2.401556
# b1_dp1_mean      1.960988
# b1_dp1_med       1.894110
# b2_dp1_mean      0.773929
# b2_dp1_med       0.753245
# b3_dp1_mean     -0.094053
# b3_dp1_med      -0.080666
# dtype: float64

# %%
df_key.kurtosis()
# Out:
# bio_agb_kg1ha    3.882544
# b1_dp1_mean      5.401935
# b1_dp1_med       4.931768
# b2_dp1_mean      0.154846
# b2_dp1_med       0.071111
# b3_dp1_mean     -0.414326
# b3_dp1_med      -0.437841
# dtype: float64

# %% [markdown]
# ### Shapiro-Wilk test

# %% [markdown]
# Shapiro-Wilk test on the distribution.
# P-values less than 0.05 indicate that we can reject the null hypothesis of normal distribution.

# %% [markdown]
# Note: non normal distribution may limit the models (i.e. linear regression)

# %%
for var in key_var[1:]:

      stat, p = scistat.shapiro(df_key[var].dropna())

      print("feature=", var, "     p-value=", '{:.6f}'.format(p))
# Out:
# feature= b1_dp1_mean      p-value= 0.000000
# feature= b1_dp1_med      p-value= 0.000000
# feature= b2_dp1_mean      p-value= 0.002671
# feature= b2_dp1_med      p-value= 0.002652
# feature= b3_dp1_mean      p-value= 0.405598
# feature= b3_dp1_med      p-value= 0.456068

# %% [markdown]
# ## Identifying extreme values and outliers in univariate analysis

# %%
df_key
# Out:
#        bio_agb_kg1ha  b1_dp1_mean  b1_dp1_med  b2_dp1_mean  b2_dp1_med  \
# uid_x
# 37          0.000000     9.666667         8.0    11.555556        13.0
# 39          0.000000     6.111111         6.0     4.444444         4.0
# 38          0.000000    13.000000        14.0     4.222222         2.0
# 41          0.000000    18.888889        19.0     9.000000         8.0
# 40          0.000000     9.000000         7.0    16.222222        18.0
# ...              ...          ...         ...          ...         ...
# 169       989.555000     4.750000         4.5    52.416667        55.5
# 122       978.739611     8.000000         8.0    55.166667        56.0
# 118      1358.280000     2.555556         3.0    56.111111        56.0
# 119      1157.053333     4.444444         4.0    33.666667        35.0
# 120       970.200000    15.000000        14.0    40.750000        40.5
#
#        b3_dp1_mean  b3_dp1_med
# uid_x
# 37       77.222222        81.0
# 39       87.777778        89.0
# 38       81.666667        83.0
# 41       70.777778        72.0
# 40       73.555556        72.0
# ...            ...         ...
# 169      41.416667        39.0
# 122      35.000000        35.0
# 118      40.000000        40.0
# 119      60.111111        59.0
# 120      42.833333        41.5
#
# [67 rows x 7 columns]

# %%
var_ = "bio_agb_kg1ha"

# %%
thirdq, firstq = df_key[var_].quantile(0.75), df_key[var_].quantile(0.25)
interquartilerange = 1.5*(thirdq-firstq)
extvalhigh, extvallow = interquartilerange+thirdq, firstq-interquartilerange
print(extvallow, extvalhigh, sep=" <--> ")
# Out:
# -9015.15999975 <--> 15370.22666625

# %%
df.loc[df[var_]>extvalhigh].T
# Out:
# uid_x                  126          128          129          130  \
# site            NTAGFU0004   NTAGFU0006   NTAGFU0007   NTAGFU0008
# bio_agb_kg1ha  1.29347e+07  1.29347e+07  1.29347e+07  1.29347e+07
# b1_dp1_min              30           12           22           17
# b1_dp1_max              46           26           30           28
# b1_dp1_mean          39.75      20.1111      24.3333      21.2222
# b1_dp1_std         4.60299      3.69518      2.74874      3.45697
# b1_dp1_med              40           20           24           21
# b1_dp1_p25              37           19           22           18
# b1_dp1_p50              40           20           24           21
# b1_dp1_p75              44           22           25           23
# b1_dp1_p95           45.45         25.2         29.2         26.8
# b1_dp1_p99           45.89        25.84        29.84        27.76
# b2_dp1_min              22           12            3            4
# b2_dp1_max              27           27           16           12
# b2_dp1_mean          24.25      19.5556      8.88889      7.33333
# b2_dp1_std         1.87639      4.78681      4.33191      2.90593
# b2_dp1_med            24.5           19            7            7
# b2_dp1_p25              22           17            6            4
# b2_dp1_p50            24.5           19            7            7
# b2_dp1_p75              26           23           12            9
# b2_dp1_p95           26.45         26.2         15.6         11.6
# b2_dp1_p99           26.89        26.84        15.92        11.92
# b3_dp1_min              26           52           56           59
# b3_dp1_max              45           68           73           76
# b3_dp1_mean        34.6667      59.2222      65.1111      70.1111
# b3_dp1_med            34.5           57           66           71
# b3_dp1_p25           31.75           56           61           67
# b3_dp1_p50            34.5           57           66           71
# b3_dp1_p75            36.5           63           70           74
# b3_dp1_p95           42.25         67.2         72.6           76
# b3_dp1_p99           44.45        67.84        72.92           76
# b3_dp1_std         4.66071      5.09417      5.74349      5.38402
#
# uid_x                  139          140      55       56           145  \
# site            NTAGFU0017   NTAGFU0018  girra01   hshr01   NTAGFU0023
# bio_agb_kg1ha  1.29347e+07  1.29347e+07  17994.8  35199.7  1.29347e+07
# b1_dp1_min               7            4        9        1            7
# b1_dp1_max              29           19       28        5           16
# b1_dp1_mean        19.4375         9.75  14.3333  2.44444      11.5625
# b1_dp1_std         7.27984       4.2451  6.58281  1.06574      2.62128
# b1_dp1_med            21.5          8.5       10        2           11
# b1_dp1_p25           12.75         6.75       10        2         9.75
# b1_dp1_p50            21.5          8.5       10        2           11
# b1_dp1_p75              26        13.25       18        3        13.25
# b1_dp1_p95              29        16.25       26      4.2           16
# b1_dp1_p99              29        18.45     27.6     4.84           16
# b2_dp1_min              17           14       24       66           28
# b2_dp1_max              29           38       55       80           47
# b2_dp1_mean        22.0625      23.8333  45.2222  74.4444      38.0625
# b2_dp1_std         3.71599      7.66848  11.1831  4.76354      6.06701
# b2_dp1_med            21.5         21.5       51       75         38.5
# b2_dp1_p25              19        17.75       49       71        34.75
# b2_dp1_p50            21.5         21.5       51       75         38.5
# b2_dp1_p75            24.5        29.75       51       79        43.25
# b2_dp1_p95           28.25        36.35     53.4     79.6         45.5
# b2_dp1_p99           28.85        37.67    54.68    79.92         46.7
# b3_dp1_min              52           46       32       17           42
# b3_dp1_max              70           77       51       29           64
# b3_dp1_mean             57      64.6667       39  21.8889       48.625
# b3_dp1_med              56         70.5       38       21           48
# b3_dp1_p25           53.75         54.5       37       18           43
# b3_dp1_p50              56         70.5       38       21           48
# b3_dp1_p75            58.5           74       38       26        49.25
# b3_dp1_p95           64.75         75.9       49     28.6        61.75
# b3_dp1_p99           68.95        76.78     50.6    28.92        63.55
# b3_dp1_std         4.65027      11.2867  5.55778  4.43332      6.63207
#
# uid_x               57       58       54        1            165
# site              hsf01    hsf02     ep01     lit01   NTAMGD0002
# bio_agb_kg1ha   25701.7  26636.3  18757.2   25585.1  1.29347e+07
# b1_dp1_min            1        1        1         1           55
# b1_dp1_max            3        6        2         2           64
# b1_dp1_mean     1.91667  3.33333      1.5   1.33333      59.3333
# b1_dp1_std     0.493007  1.63299      0.5  0.471405      3.12694
# b1_dp1_med            2        3      1.5         1           58
# b1_dp1_p25            2        2        1         1           58
# b1_dp1_p50            2        3      1.5         1           58
# b1_dp1_p75            2        5        2         2           62
# b1_dp1_p95         2.45      5.6        2         2         63.6
# b1_dp1_p99         2.89     5.92        2         2        63.92
# b2_dp1_min           60       54       84        62            1
# b2_dp1_max           65       62       89        72            3
# b2_dp1_mean     63.0833  56.6667     87.5   67.4167      1.77778
# b2_dp1_std      1.32025  2.58199  1.55456    2.8419     0.628539
# b2_dp1_med         63.5       55       88        68            2
# b2_dp1_p25           62       55       87     65.75            1
# b2_dp1_p50         63.5       55       88        68            2
# b2_dp1_p75           64       58       89        69            2
# b2_dp1_p95        64.45     61.2       89     71.45          2.6
# b2_dp1_p99        64.89    61.84       89     71.89         2.92
# b3_dp1_min           32       35        7        26           33
# b3_dp1_max           36       41       12        36           42
# b3_dp1_mean     33.5833  38.5556  9.33333   29.6667      37.5556
# b3_dp1_med         33.5       39        9      28.5           37
# b3_dp1_p25        32.75       38        8        28           36
# b3_dp1_p50         33.5       39        9      28.5           37
# b3_dp1_p75        34.25       39    10.25      30.5           39
# b3_dp1_p95        35.45     40.6       12      34.9           42
# b3_dp1_p99        35.89    40.92       12     35.78           42
# b3_dp1_std      1.25554  1.64054  1.64992   2.83823      3.02255

# %% [markdown]
# The Howard Springs outliers may be explained by the dense woody veg

# %%
df.mean()
# Out:
# bio_agb_kg1ha    1.547971e+06
# b1_dp1_min       1.055224e+01
# b1_dp1_max       2.098507e+01
# b1_dp1_mean      1.538568e+01
# b1_dp1_std       3.192746e+00
# b1_dp1_med       1.523134e+01
# b1_dp1_p25       1.337687e+01
# b1_dp1_p50       1.523134e+01
# b1_dp1_p75       1.720896e+01
# b1_dp1_p95       2.005075e+01
# b1_dp1_p99       2.079821e+01
# b2_dp1_min       2.246269e+01
# b2_dp1_max       3.468657e+01
# b2_dp1_mean      2.841490e+01
# b2_dp1_std       3.760401e+00
# b2_dp1_med       2.841791e+01
# b2_dp1_p25       2.610075e+01
# b2_dp1_p50       2.841791e+01
# b2_dp1_p75       3.079478e+01
# b2_dp1_p95       3.353582e+01
# b2_dp1_p99       3.445642e+01
# b3_dp1_min       4.800000e+01
# b3_dp1_max       6.174627e+01
# b3_dp1_mean      5.474306e+01
# b3_dp1_med       5.467910e+01
# b3_dp1_p25       5.199254e+01
# b3_dp1_p50       5.467910e+01
# b3_dp1_p75       5.740299e+01
# b3_dp1_p95       6.067910e+01
# b3_dp1_p99       6.153284e+01
# b3_dp1_std       4.252007e+00
# dtype: float64

# %%
df_out = df.loc[df[var_]<extvalhigh]

# %%
df_out.shape
# Out:
# (53, 32)

# %%
df_key_out = df_key.loc[df_key[var_]<extvalhigh]

# %%
df_key_out.shape
# Out:
# (53, 7)

# %%
df_out.mean()
# Out:
# bio_agb_kg1ha    1633.169178
# b1_dp1_min         10.169811
# b1_dp1_max         20.792453
# b1_dp1_mean        15.103381
# b1_dp1_std          3.233792
# b1_dp1_med         15.037736
# b1_dp1_p25         13.113208
# b1_dp1_p50         15.037736
# b1_dp1_p75         16.839623
# b1_dp1_p95         19.804717
# b1_dp1_p99         20.594906
# b2_dp1_min         19.886792
# b2_dp1_max         32.113208
# b2_dp1_mean        25.730215
# b2_dp1_std          3.692839
# b2_dp1_med         25.707547
# b2_dp1_p25         23.349057
# b2_dp1_p50         25.707547
# b2_dp1_p75         27.995283
# b2_dp1_p95         30.853774
# b2_dp1_p99         31.861321
# b3_dp1_min         50.962264
# b3_dp1_max         64.471698
# b3_dp1_mean        57.713181
# b3_dp1_med         57.632075
# b3_dp1_p25         55.070755
# b3_dp1_p50         57.632075
# b3_dp1_p75         60.448113
# b3_dp1_p95         63.443396
# b3_dp1_p99         64.266038
# b3_dp1_std          4.170476
# dtype: float64

# %%
def getextremevalues(dfin):
    
    dfout = pd.DataFrame(columns=dfin.columns, data=None)
    for col in dfin.columns[1:]:
        thirdq, firstq = dfin[col].quantile(0.75), dfin[col].quantile(0.25)
        interquartilerange = 1.5*(thirdq-firstq)
        extvalhigh, extvallow = interquartilerange+thirdq, firstq-interquartilerange
        #print(extvalhigh, extvallow)
        
        extreme_df = dfin.loc[(dfin[col]>extvalhigh) | (dfin[col]<extvallow)]
        #print(extreme_df)
        print(list(extreme_df))

# %%
getextremevalues(df_key)
# Out:
# ['bio_agb_kg1ha', 'b1_dp1_mean', 'b1_dp1_med', 'b2_dp1_mean', 'b2_dp1_med', 'b3_dp1_mean', 'b3_dp1_med']
# ['bio_agb_kg1ha', 'b1_dp1_mean', 'b1_dp1_med', 'b2_dp1_mean', 'b2_dp1_med', 'b3_dp1_mean', 'b3_dp1_med']
# ['bio_agb_kg1ha', 'b1_dp1_mean', 'b1_dp1_med', 'b2_dp1_mean', 'b2_dp1_med', 'b3_dp1_mean', 'b3_dp1_med']
# ['bio_agb_kg1ha', 'b1_dp1_mean', 'b1_dp1_med', 'b2_dp1_mean', 'b2_dp1_med', 'b3_dp1_mean', 'b3_dp1_med']
# ['bio_agb_kg1ha', 'b1_dp1_mean', 'b1_dp1_med', 'b2_dp1_mean', 'b2_dp1_med', 'b3_dp1_mean', 'b3_dp1_med']
# ['bio_agb_kg1ha', 'b1_dp1_mean', 'b1_dp1_med', 'b2_dp1_mean', 'b2_dp1_med', 'b3_dp1_mean', 'b3_dp1_med']

# %% [markdown]
# ### QQ plot

# %% [markdown]
# Quantile-quantile (Q-Q) plots can improve our sense of that distribution by allowing us to view it graphically relative to a theoretical distribution: normal, uniform, log, or others.
#
#  - Negative skew have an umbrella-like shape
#  - Positive skew have a bowl-like shape

# %%
sm.qqplot(df_out[[var_]].sort_values([var_]).dropna(),line='s')
plt.show()

# %% [markdown]
# Indicating a positive skew

# %%
for i in key_var:
    plt.hist(df_out[i], bins=7)
    plt.axvline(df_out[i].mean(), color='red',
    linestyle='dashed', linewidth=1, label='mean')
    plt.axvline(df_out[i].median(), color='black',
    linestyle='dashed', linewidth=1, label='median')
    plt.title(i.title().replace("_", " ") + " distribution")
    plt.xlabel('Number of sites')
    plt.ylabel(i.title().replace("_", " ") + " values")
    plt.legend()

    plt.show()
    
    sm.qqplot(df_out[[i]].sort_values([i]).dropna(),line='s')
    plt.title(i.title().replace("_", " "))
    plt.show()
    
    plt.boxplot(df_out[i].dropna(), labels=[i])
    plt.title(i.title().replace("_", " "))
    plt.show()
    
    sns.violinplot(x=df_out[i])
    plt.show()
    print("="*50)
# Out:
# ==================================================
# ==================================================
# ==================================================
# ==================================================
# ==================================================
# ==================================================
# ==================================================

# %% [markdown]
# Violin plot:
#  - the black bar with the white dot in the middle is the interquartile range
#  - the white dot represents the median.
#  - the height at each point (when the violin plot is horizontal) gives us the relative frequency.
#  - the thin black lines to the right/left of the interquartile range are the whiskers
#  - the extreme values are shown in the part of the distribution beyond the whiskers

# %%
df_key_out.skew()
# Out:
# bio_agb_kg1ha    2.311351
# b1_dp1_mean      2.221204
# b1_dp1_med       2.152632
# b2_dp1_mean      0.352179
# b2_dp1_med       0.354420
# b3_dp1_mean      0.112335
# b3_dp1_med       0.105830
# dtype: float64

# %%
df_key_out.kurtosis()
# Out:
# bio_agb_kg1ha    5.746851
# b1_dp1_mean      7.829767
# b1_dp1_med       7.191489
# b2_dp1_mean     -1.120620
# b2_dp1_med      -1.073714
# b3_dp1_mean     -0.841226
# b3_dp1_med      -0.754747
# dtype: float64

# %%
for var in key_var:

      stat, p = scistat.shapiro(df_key[var].dropna())

      print("feature=", var, "     p-value =", '{:.6f}'.format(p))
# Out:
# feature= bio_agb_kg1ha      p-value = 0.000000
# feature= b1_dp1_mean      p-value = 0.000000
# feature= b1_dp1_med      p-value = 0.000000
# feature= b2_dp1_mean      p-value = 0.002671
# feature= b2_dp1_med      p-value = 0.002652
# feature= b3_dp1_mean      p-value = 0.405598
# feature= b3_dp1_med      p-value = 0.456068

# %%
thirdq, firstq = df_key_out[var_].quantile(0.75), df_key_out[var_].quantile(0.25)
interquartilerange = 1.5*(thirdq-firstq)
extvalhigh, extvallow = interquartilerange+thirdq, firstq-interquartilerange
print(extvallow, extvalhigh, sep=" <--> ")
# Out:
# -2934.855 <--> 4891.425

# %%
df.loc[df[var_]>extvalhigh].T
# Out:
# uid_x                  126          128          129          130  \
# site            NTAGFU0004   NTAGFU0006   NTAGFU0007   NTAGFU0008
# bio_agb_kg1ha  1.29347e+07  1.29347e+07  1.29347e+07  1.29347e+07
# b1_dp1_min              30           12           22           17
# b1_dp1_max              46           26           30           28
# b1_dp1_mean          39.75      20.1111      24.3333      21.2222
# b1_dp1_std         4.60299      3.69518      2.74874      3.45697
# b1_dp1_med              40           20           24           21
# b1_dp1_p25              37           19           22           18
# b1_dp1_p50              40           20           24           21
# b1_dp1_p75              44           22           25           23
# b1_dp1_p95           45.45         25.2         29.2         26.8
# b1_dp1_p99           45.89        25.84        29.84        27.76
# b2_dp1_min              22           12            3            4
# b2_dp1_max              27           27           16           12
# b2_dp1_mean          24.25      19.5556      8.88889      7.33333
# b2_dp1_std         1.87639      4.78681      4.33191      2.90593
# b2_dp1_med            24.5           19            7            7
# b2_dp1_p25              22           17            6            4
# b2_dp1_p50            24.5           19            7            7
# b2_dp1_p75              26           23           12            9
# b2_dp1_p95           26.45         26.2         15.6         11.6
# b2_dp1_p99           26.89        26.84        15.92        11.92
# b3_dp1_min              26           52           56           59
# b3_dp1_max              45           68           73           76
# b3_dp1_mean        34.6667      59.2222      65.1111      70.1111
# b3_dp1_med            34.5           57           66           71
# b3_dp1_p25           31.75           56           61           67
# b3_dp1_p50            34.5           57           66           71
# b3_dp1_p75            36.5           63           70           74
# b3_dp1_p95           42.25         67.2         72.6           76
# b3_dp1_p99           44.45        67.84        72.92           76
# b3_dp1_std         4.66071      5.09417      5.74349      5.38402
#
# uid_x                  139          140      55       56           145  \
# site            NTAGFU0017   NTAGFU0018  girra01   hshr01   NTAGFU0023
# bio_agb_kg1ha  1.29347e+07  1.29347e+07  17994.8  35199.7  1.29347e+07
# b1_dp1_min               7            4        9        1            7
# b1_dp1_max              29           19       28        5           16
# b1_dp1_mean        19.4375         9.75  14.3333  2.44444      11.5625
# b1_dp1_std         7.27984       4.2451  6.58281  1.06574      2.62128
# b1_dp1_med            21.5          8.5       10        2           11
# b1_dp1_p25           12.75         6.75       10        2         9.75
# b1_dp1_p50            21.5          8.5       10        2           11
# b1_dp1_p75              26        13.25       18        3        13.25
# b1_dp1_p95              29        16.25       26      4.2           16
# b1_dp1_p99              29        18.45     27.6     4.84           16
# b2_dp1_min              17           14       24       66           28
# b2_dp1_max              29           38       55       80           47
# b2_dp1_mean        22.0625      23.8333  45.2222  74.4444      38.0625
# b2_dp1_std         3.71599      7.66848  11.1831  4.76354      6.06701
# b2_dp1_med            21.5         21.5       51       75         38.5
# b2_dp1_p25              19        17.75       49       71        34.75
# b2_dp1_p50            21.5         21.5       51       75         38.5
# b2_dp1_p75            24.5        29.75       51       79        43.25
# b2_dp1_p95           28.25        36.35     53.4     79.6         45.5
# b2_dp1_p99           28.85        37.67    54.68    79.92         46.7
# b3_dp1_min              52           46       32       17           42
# b3_dp1_max              70           77       51       29           64
# b3_dp1_mean             57      64.6667       39  21.8889       48.625
# b3_dp1_med              56         70.5       38       21           48
# b3_dp1_p25           53.75         54.5       37       18           43
# b3_dp1_p50              56         70.5       38       21           48
# b3_dp1_p75            58.5           74       38       26        49.25
# b3_dp1_p95           64.75         75.9       49     28.6        61.75
# b3_dp1_p99           68.95        76.78     50.6    28.92        63.55
# b3_dp1_std         4.65027      11.2867  5.55778  4.43332      6.63207
#
# uid_x               57       58       60       54       104       105  \
# site              hsf01    hsf02   wedo03     ep01   legu06    legu07
# bio_agb_kg1ha   25701.7  26636.3  11338.1  18757.2   7715.4   9708.97
# b1_dp1_min            1        1        3        1        1         1
# b1_dp1_max            3        6       15        2        6         3
# b1_dp1_mean     1.91667  3.33333     8.25      1.5   2.8125   1.77778
# b1_dp1_std     0.493007  1.63299  3.19179      0.5  1.23586  0.628539
# b1_dp1_med            2        3        8      1.5      2.5         2
# b1_dp1_p25            2        2      6.5        1        2         1
# b1_dp1_p50            2        3        8      1.5      2.5         2
# b1_dp1_p75            2        5    10.25        2        3         2
# b1_dp1_p95         2.45      5.6    12.75        2     5.25       2.6
# b1_dp1_p99         2.89     5.92    14.55        2     5.85      2.92
# b2_dp1_min           60       54       45       84       48        42
# b2_dp1_max           65       62       59       89       55        48
# b2_dp1_mean     63.0833  56.6667  52.3125     87.5   51.375        45
# b2_dp1_std      1.32025  2.58199  4.14908  1.55456  1.57619   1.76383
# b2_dp1_med         63.5       55       53       88       51        45
# b2_dp1_p25           62       55       49       87    50.75        44
# b2_dp1_p50         63.5       55       53       88       51        45
# b2_dp1_p75           64       58    55.25       89    52.25        46
# b2_dp1_p95        64.45     61.2    58.25       89     53.5      47.6
# b2_dp1_p99        64.89    61.84    58.85       89     54.7     47.92
# b3_dp1_min           32       35       31        7       40        49
# b3_dp1_max           36       41       42       12       48        55
# b3_dp1_mean     33.5833  38.5556  37.9375  9.33333   44.125   51.7778
# b3_dp1_med         33.5       39       38        9       44        52
# b3_dp1_p25        32.75       38       37        8    43.75        51
# b3_dp1_p50         33.5       39       38        9       44        52
# b3_dp1_p75        34.25       39    39.25    10.25       45        53
# b3_dp1_p95        35.45     40.6     40.5       12    47.25      54.6
# b3_dp1_p99        35.89    40.92     41.7       12    47.85     54.92
# b3_dp1_std      1.25554  1.64054   2.4101  1.64992  1.93245   1.93091
#
# uid_x               1            165
# site              lit01   NTAMGD0002
# bio_agb_kg1ha   25585.1  1.29347e+07
# b1_dp1_min            1           55
# b1_dp1_max            2           64
# b1_dp1_mean     1.33333      59.3333
# b1_dp1_std     0.471405      3.12694
# b1_dp1_med            1           58
# b1_dp1_p25            1           58
# b1_dp1_p50            1           58
# b1_dp1_p75            2           62
# b1_dp1_p95            2         63.6
# b1_dp1_p99            2        63.92
# b2_dp1_min           62            1
# b2_dp1_max           72            3
# b2_dp1_mean     67.4167      1.77778
# b2_dp1_std       2.8419     0.628539
# b2_dp1_med           68            2
# b2_dp1_p25        65.75            1
# b2_dp1_p50           68            2
# b2_dp1_p75           69            2
# b2_dp1_p95        71.45          2.6
# b2_dp1_p99        71.89         2.92
# b3_dp1_min           26           33
# b3_dp1_max           36           42
# b3_dp1_mean     29.6667      37.5556
# b3_dp1_med         28.5           37
# b3_dp1_p25           28           36
# b3_dp1_p50         28.5           37
# b3_dp1_p75         30.5           39
# b3_dp1_p95         34.9           42
# b3_dp1_p99        35.78           42
# b3_dp1_std      2.83823      3.02255

# %%
df_key_out_out = df_key.loc[df_key[var_]<extvalhigh]

# %%
for i in key_var:
    plt.hist(df_key_out_out[i], bins=7)
    plt.axvline(df_key_out_out[i].mean(), color='red',
    linestyle='dashed', linewidth=1, label='mean')
    plt.axvline(df_key_out_out[i].median(), color='black',
    linestyle='dashed', linewidth=1, label='median')
    plt.title(i.title().replace("_", " ") + " distribution")
    plt.xlabel('Number of sites')
    plt.ylabel(i.title().replace("_", " ") + " values")
    plt.legend()

    plt.show()
    
    sm.qqplot(df_key_out_out[[i]].sort_values([i]).dropna(),line='s')
    plt.title(i.title().replace("_", " "))
    plt.show()
    
    plt.boxplot(df_key_out_out[i].dropna(), labels=[i])
    plt.title(i.title().replace("_", " "))
    plt.show()
    
    sns.violinplot(x=df_key_out_out[i])
    plt.show()
    print("="*50)
# Out:
# ==================================================
# ==================================================
# ==================================================
# ==================================================
# ==================================================
# ==================================================
# ==================================================
