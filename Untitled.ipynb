# %%
import os

# %%
path_ = r"D:\met_analysis\nt\dlyrn\cor"
path_ = r"F:\fire_analysis\nt\nul255"

# %%
list_of_files = os.listdir(path_)

# %%
for f in list_of_files:
    orig = os.path.join(path_, f)
    rf = f.replace("msuma2", "dcora2")
    out = os.path.join(path_, rf)
    print(f"{orig} to {out}")
    os.rename(orig, out)
# Out:
# D:\met_analysis\nt\morat\cor\morat_nt_19930101_msuma2.tif to D:\met_analysis\nt\morat\cor\morat_nt_19930101_dcora2.tif
# D:\met_analysis\nt\morat\cor\morat_nt_19930102_msuma2.tif to D:\met_analysis\nt\morat\cor\morat_nt_19930102_dcora2.tif
# D:\met_analysis\nt\morat\cor\morat_nt_19930103_msuma2.tif to D:\met_analysis\nt\morat\cor\morat_nt_19930103_dcora2.tif
# D:\met_analysis\nt\morat\cor\morat_nt_19930104_msuma2.tif to D:\met_analysis\nt\morat\cor\morat_nt_19930104_dcora2.tif
# D:\met_analysis\nt\morat\cor\morat_nt_19930105_msuma2.tif to D:\met_analysis\nt\morat\cor\morat_nt_19930105_dcora2.tif
# D:\met_analysis\nt\morat\cor\morat_nt_19930106_msuma2.tif to D:\met_analysis\nt\morat\cor\morat_nt_19930106_dcora2.tif
# D:\met_analysis\nt\morat\cor\morat_nt_19930107_msuma2.tif to D:\met_analysis\nt\morat\cor\morat_nt_19930107_dcora2.tif
# D:\met_analysis\nt\morat\cor\morat_nt_19930108_msuma2.tif to D:\met_analysis\nt\morat\cor\morat_nt_19930108_dcora2.tif
# ...

# %%
for f in list_of_files:
    orig = os.path.join(path_, f)
    rf = f.replace("nula__2", "nula2")
    out = os.path.join(path_, rf)
    print(f"{orig} to {out}")
    os.rename(orig, out)
# Out:
# F:\fire_analysis\nt\nul255\brnsc_nt_198801198812_nula__2.tif to F:\fire_analysis\nt\nul255\brnsc_nt_198801198812_nula2.tif
# F:\fire_analysis\nt\nul255\brnsc_nt_198801198812_nula__2.ige to F:\fire_analysis\nt\nul255\brnsc_nt_198801198812_nula2.ige
# F:\fire_analysis\nt\nul255\brnsc_nt_198801198812_nula__2.tif.aux.xml to F:\fire_analysis\nt\nul255\brnsc_nt_198801198812_nula2.tif.aux.xml
# F:\fire_analysis\nt\nul255\brnsc_nt_198701198712_nula__2.tif to F:\fire_analysis\nt\nul255\brnsc_nt_198701198712_nula2.tif
# F:\fire_analysis\nt\nul255\brnsc_nt_198701198712_nula__2.ige to F:\fire_analysis\nt\nul255\brnsc_nt_198701198712_nula2.ige
# F:\fire_analysis\nt\nul255\brnsc_nt_198701198712_nula__2.rrd to F:\fire_analysis\nt\nul255\brnsc_nt_198701198712_nula2.rrd
# F:\fire_analysis\nt\nul255\brnsc_nt_198701198712_nula__2.rde to F:\fire_analysis\nt\nul255\brnsc_nt_198701198712_nula2.rde
# ...
