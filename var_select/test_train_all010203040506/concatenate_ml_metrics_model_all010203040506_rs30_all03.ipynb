# %% [markdown]
# C:\Users\robot\code\ml\landsat\collate_validation_metrics.py

# %%
# !conda info
# Out:
#      active environment : tf_grid2.13
#     active env location : C:\Users\robot\anaconda3\envs\tf_grid2.13
#             shell level : 1
#        user config file : C:\Users\robot\.condarc
#  populated config files : C:\Users\robot\.condarc
#           conda version : 23.7.4
#     conda-build version : 3.26.1
#          python version : 3.11.5.final.0
#        virtual packages : __archspec=1=x86_64
#                           __cuda=12.6=0
#                           __win=0=0
#        base environment : C:\Users\robot\anaconda3  (writable)
#       conda av data dir : C:\Users\robot\anaconda3\etc\conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/win-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/win-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://repo.anaconda.com/pkgs/msys2/win-64
#                           https://repo.anaconda.com/pkgs/msys2/noarch
#           package cache : C:\Users\robot\anaconda3\pkgs
#                           C:\Users\robot\.conda\pkgs
#                           C:\Users\robot\AppData\Local\conda\conda\pkgs
#        envs directories : C:\Users\robot\anaconda3\envs
#                           C:\Users\robot\.conda\envs
#                           C:\Users\robot\AppData\Local\conda\conda\envs
#                platform : win-64
#              user-agent : conda/23.7.4 requests/2.31.0 CPython/3.11.5 Windows/10 Windows/10.0.22631 aau/0.4.2 c/GCfBIDUHhxps2cQbZNHX2w s/iuPKpaDyxawZHUmPUEWVRA e/Xu4hNux8FAw-jhfM-IcOHQ
#           administrator : False
#              netrc file : None
#            offline mode : False

# %%
import os
import pandas as pd
import math
import ast
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import display, Markdown
# %matplotlib inline

# Disable scientific notation for pandas display
pd.set_option('display.float_format', lambda x: '%.10f' % x)

# %%
# Directory path to search through
directory_ = r'H:\biomass'
model_run = "test_train_all04_05"
model_run = "model_all01_02_03_04_05_06_v2"


directory_path = os.path.join(directory_, f"model_{model_run}")

combined_df = pd.read_csv(os.path.join(directory_path, "total_metrics.csv"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 9
#       4 model_run = "model_all01_02_03_04_05_06_v2"
#       7 directory_path = os.path.join(directory_, f"model_{model_run}")
# ----> 9 combined_df = pd.read_csv(os.path.join(directory_path, "total_metrics.csv"))
#
# File ~\anaconda3\envs\tf_grid2.13\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\tf_grid2.13\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\anaconda3\envs\tf_grid2.13\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\envs\tf_grid2.13\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\anaconda3\envs\tf_grid2.13\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'H:\\biomass\\model_model_all01_02_03_04_05_06_v2\\total_metrics.csv'

# %%
# Directory path to search through
directory_ = r'H:\biomass'
model_run = "test_train_mlp"
model_run = "model_all01_02_03_04_05_06_v2"

directory_path = os.path.join(directory_, f"{model_run}")

combined_df = pd.read_csv(os.path.join(directory_path, "total_metrics.csv"))

# %% [markdown]
# ## Split into groups based on status

# %%
retrain_df = combined_df[combined_df["status"]=="retrain"]
retest_df = combined_df[combined_df["status"]=="retest"]

# %%
retest_df
# Out:
#                 r2                  mse             rmse             mae  \
# 0     0.1400000000  47348298.4600000009  6881.0100000000 4700.6300000000
# 1     0.1000000000  49606148.6000000015  7043.1600000000 4906.4600000000
# 2     0.1000000000  49518113.4600000009  7036.9100000000 4830.7200000000
# 3     0.1200000000  48394383.8100000024  6956.6100000000 4874.5000000000
# 4     0.1200000000  48206650.4299999997  6943.1000000000 4762.8300000000
# ...            ...                  ...              ...             ...
# 1723 -0.2400000000  94715169.9000000060  9732.1700000000 6694.2600000000
# 1724 -0.2900000000  98545977.7500000000  9927.0300000000 6777.1600000000
# 1725 -0.4500000000 111043548.4500000030 10537.7200000000 7157.4100000000
# 1726 -0.5200000000 116219984.4599999934 10780.5400000000 7305.2800000000
# 1727 -0.5500000000 118916555.4500000030 10904.8900000000 7283.7900000000
#
#                       mape            bias   n  mdl  status         var   fac  \
# 0    1242035923.6400001049  133.5500000000  36  RFR  retest  all03_rs30    r2
# 1    1281912647.5799999237   72.8900000000  36  RFR  retest  all03_rs30    r2
# 2    1236456114.5199999809  263.7400000000  36  RFR  retest  all03_rs30    r2
# 3    1380282916.7699999809  -66.9200000000  36  RFR  retest  all03_rs30    r2
# 4    1321358471.8199999332   98.4100000000  36  RFR  retest  all03_rs30    r2
# ...                    ...             ...  ..  ...     ...         ...   ...
# 1723  270760487.1700000167 5987.9200000000  38  MLP  retest  all01_rs30  RMSE
# 1724  236159201.5300000012 6186.5800000000  38  MLP  retest  all01_rs30  RMSE
# 1725  216475460.2299999893 6608.0200000000  38  MLP  retest  all01_rs30  RMSE
# 1726  210725510.4699999988 6773.1400000000  38  MLP  retest  all01_rs30  RMSE
# 1727  122679110.4899999946 6989.4500000000  38  MLP  retest  all01_rs30  RMSE
#
#       stdev  sel_num  data stats  \
# 0         3       40  all0  mean
# 1         3       25  all0  mean
# 2         3       20  all0  mean
# 3         3       15  all0  mean
# 4         3       12  all0  mean
# ...     ...      ...   ...   ...
# 1723      3       25  all0   p99
# 1724      3       20  all0   p99
# 1725      3       15  all0   p99
# 1726      3       12  all0   p99
# 1727      3       10  all0   p99
#
#                                                features  \
# 0     ['b1_h99_mean', 'b1_hsd_mean', 'b6_dbifm_mean'...
# 1     ['b1_hsd_mean', 'b1_h25_mean', 'b1_hmc_mean', ...
# 2     ['b1_wfp_dry_mean', 'b1_dbifm_mean', 'b3_dp1fm...
# 3     ['b1_dp1fm_dry_mean', 'b1_dp1fm_mean', 'b1_hmc...
# 4     ['b1_dp1fm_mean', 'b2_dp1fm_mean', 'b1_h25_mea...
# ...                                                 ...
# 1723  ['b1_dp1fm_p99', 'b1_dp1fm_dry_p99', 'b2_dp1fm...
# 1724  ['dbifman_GNDVI', 'dbifman_GDVI', 'dbifman_NDV...
# 1725  ['b2_dbifm_p99', 'b3_dp1fm_p99', 'b3_dbifm_p99...
# 1726  ['dbifmdry_GNDVI', 'dbifman_GNDVI', 'b2_dp1fm_...
# 1727  ['b3_dp1fm_p99', 'b1_dp1fm_p99', 'b1_dbifm_p99...
#
#                                                   model  \
# 0     RandomForestRegressor(bootstrap=False, max_dep...
# 1     RandomForestRegressor(bootstrap=False, max_dep...
# 2     RandomForestRegressor(bootstrap=False, max_dep...
# 3     RandomForestRegressor(bootstrap=False, max_dep...
# 4     RandomForestRegressor(bootstrap=False, max_dep...
# ...                                                 ...
# 1723  Pipeline(steps=[('scaler', StandardScaler()),\...
# 1724  Pipeline(steps=[('scaler', StandardScaler()),\...
# 1725  Pipeline(steps=[('scaler', StandardScaler()),\...
# 1726  Pipeline(steps=[('scaler', StandardScaler()),\...
# 1727  Pipeline(steps=[('scaler', StandardScaler()),\...
#
#                                                file
# 0       all03_rs30_r2_RFR_sel_40_variable_score.csv
# 1       all03_rs30_r2_RFR_sel_25_variable_score.csv
# 2       all03_rs30_r2_RFR_sel_20_variable_score.csv
# 3       all03_rs30_r2_RFR_sel_15_variable_score.csv
# 4       all03_rs30_r2_RFR_sel_12_variable_score.csv
# ...                                             ...
# 1723  all01_rs30_RMSE_MLP_sel_25_variable_score.csv
# 1724  all01_rs30_RMSE_MLP_sel_20_variable_score.csv
# 1725  all01_rs30_RMSE_MLP_sel_15_variable_score.csv
# 1726  all01_rs30_RMSE_MLP_sel_12_variable_score.csv
# 1727  all01_rs30_RMSE_MLP_sel_10_variable_score.csv
#
# [1728 rows x 18 columns]

# %% [markdown]
# # Join Validation and Train together

# %%
df_merged = pd.merge(retrain_df, retest_df, on=['mdl', 'model', 'sel_num', 'fac', 'var', 'file', 'stats', 'data', 'stdev'], how='outer')

# %%
# Rename columns containing "_x" to "validation" and "_y" to "train"
df_merged.columns = df_merged.columns.str.replace('_x', '_retrain').str.replace('_y', '_retest')
df_merged
# Out:
#       r2_retrain  mse_retrain  rmse_retrain  mae_retrain  mape_retrain  \
# 0            NaN          NaN           NaN          NaN           NaN
# 1            NaN          NaN           NaN          NaN           NaN
# 2            NaN          NaN           NaN          NaN           NaN
# 3            NaN          NaN           NaN          NaN           NaN
# 4            NaN          NaN           NaN          NaN           NaN
# ...          ...          ...           ...          ...           ...
# 1723         NaN          NaN           NaN          NaN           NaN
# 1724         NaN          NaN           NaN          NaN           NaN
# 1725         NaN          NaN           NaN          NaN           NaN
# 1726         NaN          NaN           NaN          NaN           NaN
# 1727         NaN          NaN           NaN          NaN           NaN
#
#       bias_retrain  n_retrain status_retrain features_retrain     r2_retest  \
# 0              NaN        NaN            NaN              NaN  0.1400000000
# 1              NaN        NaN            NaN              NaN  0.1000000000
# 2              NaN        NaN            NaN              NaN  0.1000000000
# 3              NaN        NaN            NaN              NaN  0.1200000000
# 4              NaN        NaN            NaN              NaN  0.1200000000
# ...            ...        ...            ...              ...           ...
# 1723           NaN        NaN            NaN              NaN -0.2400000000
# 1724           NaN        NaN            NaN              NaN -0.2900000000
# 1725           NaN        NaN            NaN              NaN -0.4500000000
# 1726           NaN        NaN            NaN              NaN -0.5200000000
# 1727           NaN        NaN            NaN              NaN -0.5500000000
#
#       ...  status_retest         var   fac  stdev  sel_num  data stats  \
# 0     ...         retest  all03_rs30    r2      3       40  all0  mean
# 1     ...         retest  all03_rs30    r2      3       25  all0  mean
# 2     ...         retest  all03_rs30    r2      3       20  all0  mean
# 3     ...         retest  all03_rs30    r2      3       15  all0  mean
# 4     ...         retest  all03_rs30    r2      3       12  all0  mean
# ...   ...            ...         ...   ...    ...      ...   ...   ...
# 1723  ...         retest  all01_rs30  RMSE      3       25  all0   p99
# 1724  ...         retest  all01_rs30  RMSE      3       20  all0   p99
# 1725  ...         retest  all01_rs30  RMSE      3       15  all0   p99
# 1726  ...         retest  all01_rs30  RMSE      3       12  all0   p99
# 1727  ...         retest  all01_rs30  RMSE      3       10  all0   p99
#
#                                         features_retest  \
# 0     ['b1_h99_mean', 'b1_hsd_mean', 'b6_dbifm_mean'...
# 1     ['b1_hsd_mean', 'b1_h25_mean', 'b1_hmc_mean', ...
# 2     ['b1_wfp_dry_mean', 'b1_dbifm_mean', 'b3_dp1fm...
# 3     ['b1_dp1fm_dry_mean', 'b1_dp1fm_mean', 'b1_hmc...
# 4     ['b1_dp1fm_mean', 'b2_dp1fm_mean', 'b1_h25_mea...
# ...                                                 ...
# 1723  ['b1_dp1fm_p99', 'b1_dp1fm_dry_p99', 'b2_dp1fm...
# 1724  ['dbifman_GNDVI', 'dbifman_GDVI', 'dbifman_NDV...
# 1725  ['b2_dbifm_p99', 'b3_dp1fm_p99', 'b3_dbifm_p99...
# 1726  ['dbifmdry_GNDVI', 'dbifman_GNDVI', 'b2_dp1fm_...
# 1727  ['b3_dp1fm_p99', 'b1_dp1fm_p99', 'b1_dbifm_p99...
#
#                                                   model  \
# 0     RandomForestRegressor(bootstrap=False, max_dep...
# 1     RandomForestRegressor(bootstrap=False, max_dep...
# 2     RandomForestRegressor(bootstrap=False, max_dep...
# 3     RandomForestRegressor(bootstrap=False, max_dep...
# 4     RandomForestRegressor(bootstrap=False, max_dep...
# ...                                                 ...
# 1723  Pipeline(steps=[('scaler', StandardScaler()),\...
# 1724  Pipeline(steps=[('scaler', StandardScaler()),\...
# 1725  Pipeline(steps=[('scaler', StandardScaler()),\...
# 1726  Pipeline(steps=[('scaler', StandardScaler()),\...
# 1727  Pipeline(steps=[('scaler', StandardScaler()),\...
#
#                                                file
# 0       all03_rs30_r2_RFR_sel_40_variable_score.csv
# 1       all03_rs30_r2_RFR_sel_25_variable_score.csv
# 2       all03_rs30_r2_RFR_sel_20_variable_score.csv
# 3       all03_rs30_r2_RFR_sel_15_variable_score.csv
# 4       all03_rs30_r2_RFR_sel_12_variable_score.csv
# ...                                             ...
# 1723  all01_rs30_RMSE_MLP_sel_25_variable_score.csv
# 1724  all01_rs30_RMSE_MLP_sel_20_variable_score.csv
# 1725  all01_rs30_RMSE_MLP_sel_15_variable_score.csv
# 1726  all01_rs30_RMSE_MLP_sel_12_variable_score.csv
# 1727  all01_rs30_RMSE_MLP_sel_10_variable_score.csv
#
# [1728 rows x 27 columns]

# %%
def plot_best_model(df, model_run, model, var, data, std, display_limit):
    #df = df.sort_values(by=['rmse_retest', 'r2_retest', 'rmse_retrain', 'r2_retrain'], ascending=[True, False, True, False])
    df = df.sort_values(by=['rmse_retest'], ascending=[True])

    # Generate the Windows path
    df["file_path"] = (
        f"H:/biomass/model_{model_run}/AGB/" +
        df['var'].astype(str) + "/" +
        df['mdl'].astype(str) + "/" +
        df['stats'].astype(str) + "/std" +
        #df['stdev'].astype(str) + "/" +
        df['stdev'].astype(int).astype(str) + "/" + 
        df['data'].astype(str) + "/" +
        df['fac'].astype(str) + "/sel_num_" +
        df['sel_num'].astype(str).str[:2]
    )

    # Loop through each row in the DataFrame and print out the relevant information
    for i, row in enumerate(df.itertuples(index=False)):

        # Limit the number of displayed image sets to prevent memory overload
        if i >= display_limit:
            print("Display limit reached. Adjust the display limit to see more images.")
            break  # Stop after showing the defined number of image sets

        # Extract validation and test (retest) metrics from the row
        test_metrics = {
            'R² (retest)': getattr(row, 'r2_retest', np.nan),
            'MSE (retest)': getattr(row, 'mse_retest', np.nan),
            'RMSE (retest)': getattr(row, 'rmse_retest', np.nan),
            'MAE (retest)': getattr(row, 'mae_retest', np.nan),
            'MAPE (retest)': getattr(row, 'mape_retest', np.nan),
            'Bias (retest)': getattr(row, 'bias_retest', np.nan),
            'N (retest)': getattr(row, 'n_retest', np.nan)
        }

        retrain_metrics = {
            'R² (retrain)': getattr(row, 'r2_retrain', np.nan),
            'MSE (retrain)': getattr(row, 'mse_retrain', np.nan),
            'RMSE (retrain)': getattr(row, 'rmse_retrain', np.nan),
            'MAE (retrain)': getattr(row, 'mae_retrain', np.nan),
            'MAPE (retrain)': getattr(row, 'mape_retrain', np.nan),
            'Bias (retrain)': getattr(row, 'bias_retrain', np.nan),
            'N (retrain)': getattr(row, 'n_retrain', np.nan)
        }

        # Generate and display images (retest and validation as before)
        path = row.file_path
        print(f"Path: {path}")

        # Log the path being used to ensure the correct images are selected
        #print(f"Looking for image files in: {path}")

        # Split the path after "AGB" and keep the rest of the path
        base, after_agb = path.split("AGB", 1)

        # Replace forward slashes with underscores in the part after "AGB"
        after_agb_modified = after_agb.replace("/", "_")
        df.at[i, "apply_mdl"] = after_agb_modified[1:]  # Update the DataFrame
        print(f"If using - create directory: {after_agb_modified[1:]}")

        # Locate the directory and find files ending with retest.JPG and validation.JPG
        search_path = os.path.join(path, "*.JPG")  # Search for all JPG files in the directory

        # Get all JPG files
        jpg_files = glob.glob(search_path)

        # Filter for files ending with retest.JPG and validation.JPG
        retest_files = [file for file in jpg_files if file.endswith("retest.JPG")]
        retrain_files = [file for file in jpg_files if file.endswith("retrain.JPG")]

        # Log file paths to check which files are being imported
        if retest_files:
            print(f" - Retest Image found: {retest_files[0]}")
            #print(retest_files)
        else:
            print("No Retest Image found.")
            print("ERROR --"*50)

        if retrain_files:
            print(f" - retrain Image found: {retrain_files[0]}")
            #print(retrain_files)
        else:
            print("No retrain Image found.")
            print("ERROR --"*50)

        # **NEW** Search for files ending with retrain_distribution.JPG two sub-directories above the original path
        distribution_dir = os.path.abspath(os.path.join(path, "../.."))  # Two directories above
        distribution_search_path = os.path.join(distribution_dir, "*retrain_distribution.JPG")

        # Check if the retrain_distribution.JPG exists
        distribution_files = glob.glob(distribution_search_path)  # Search for the file

        #print("distribution_files: ", distribution_files)
        if len(distribution_files) > 0:
            #print(f"retrain Distribution Plot found at: {distribution_files[0]}")
            fig, ax = plt.subplots(figsize=(10, 8), dpi=150)  # Increase size and DPI for better quality
            retrain_distribution_img = mpimg.imread(distribution_files[0])
            ax.imshow(retrain_distribution_img)
            ax.set_title('retrain Distribution Plot', fontsize=16)  # Increased font size
            ax.axis('off')  # Turn off axis display
            plt.tight_layout()
            plt.show()

        # Plot the found JPG files (retest and retrain) side by side
        if retest_files or retrain_files:
            fig, axes = plt.subplots(1, 2, figsize=(12, 6), dpi=150)  # Larger figure and higher DPI

            # Load and display the retest image (if available)
            if retest_files:
                retest_img = mpimg.imread(retest_files[0])
                axes[0].imshow(retest_img)
                axes[0].set_title('Retest Image', fontsize=16)  # Increased font size
                axes[0].axis('off')  # Turn off axis display
            else:
                axes[0].axis('off')  # Leave the subplot blank if no image is available

            # Load and display the retrain image (if available)
            if retrain_files:
                retrain_img = mpimg.imread(retrain_files[0])
                axes[1].imshow(retrain_img)
                axes[1].set_title('retrain Image', fontsize=16)  # Increased font size
                axes[1].axis('off')  # Turn off axis display
            else:
                axes[1].axis('off')  # Leave the subplot blank if no image is available

            # Adjust layout and show the images
            plt.tight_layout(pad=2.0)  # Add padding between images
            plt.show()

            # Clear the figure from memory after displaying it
            plt.close()
            print("-" * 100)
            # Print the test and retrain metrics for comparison
            print(f"Test Metrics vs retrain Metrics for row {i}:")
            # for metric in test_metrics:
            #     print(f"{metric}: {test_metrics[metric]}"  |  {retrain_metric_name}: {retrain_metrics.get(retrain_metric_name, 'N/A')}")

            print("="*100)
        # Print the relevant features
        print(f"Features Used: {row.features_retest}")
        print("-" * 100)

    print("exported to: ", r"C:\Users\robot\code\pipelines\apply_biomass\{0}_{1}_{2}_{3}_{4}_overall_best.csv".format(
        model_run, model, var, data, std))
    # Save the updated DataFrame to a CSV file
    df.to_csv(r"C:\Users\robot\code\pipelines\apply_biomass\{0}_{1}_{2}_{3}_{4}_overall_best.csv".format(
        model_run, model, var, data, std))
    
    return df

# %%
def plot_best_model(df, model_run, model, var, data, std, display_limit):
    # Sort the DataFrame
    df = df.sort_values(by=['rmse_retest'], ascending=[True])

    # Generate the Windows path
    df["file_path"] = (
        f"H:/biomass/model_{model_run}/AGB/" +
        df['var'].astype(str) + "/" +
        df['mdl'].astype(str) + "/" +
        df['stats'].astype(str) + "/std" +
        df['stdev'].astype(int).astype(str) + "/" + 
        df['data'].astype(str) + "/" +
        df['fac'].astype(str) + "/sel_num_" +
        df['sel_num'].astype(str).str[:2]
    )

    # Loop through each row in the DataFrame and print out the relevant information
    for i, row in enumerate(df.itertuples(index=False)):

        # Limit the number of displayed image sets to prevent memory overload
        if i >= display_limit:
            print("Display limit reached. Adjust the display limit to see more images.")
            break

        # Extract validation and test (retest) metrics from the row
        test_metrics = {
            'R² (retest)': getattr(row, 'r2_retest', np.nan),
            'MSE (retest)': getattr(row, 'mse_retest', np.nan),
            'RMSE (retest)': getattr(row, 'rmse_retest', np.nan),
            'MAE (retest)': getattr(row, 'mae_retest', np.nan),
            'MAPE (retest)': getattr(row, 'mape_retest', np.nan),
            'Bias (retest)': getattr(row, 'bias_retest', np.nan),
            'N (retest)': getattr(row, 'n_retest', np.nan)
        }

        retrain_metrics = {
            'R² (retrain)': getattr(row, 'r2_retrain', np.nan),
            'MSE (retrain)': getattr(row, 'mse_retrain', np.nan),
            'RMSE (retrain)': getattr(row, 'rmse_retrain', np.nan),
            'MAE (retrain)': getattr(row, 'mae_retrain', np.nan),
            'MAPE (retrain)': getattr(row, 'mape_retrain', np.nan),
            'Bias (retrain)': getattr(row, 'bias_retrain', np.nan),
            'N (retrain)': getattr(row, 'n_retrain', np.nan)
        }

        # Generate and display images (retest and validation as before)
        path = row.file_path
        print(f"Path: {path}")
        
        # Split the path after "AGB" and keep the rest of the path
        base, after_agb = path.split("AGB", 1)

        # Replace forward slashes with underscores in the part after "AGB"
        after_agb_modified = after_agb.replace("/", "_")
        df.at[i, "apply_mdl"] = after_agb_modified[1:]  # Update the DataFrame
        print(f"If using - create directory: {after_agb_modified[1:]}")

        # Locate the directory and find files ending with retest.JPG and validation.JPG
        search_path = os.path.join(path, "*.JPG")  # Search for all JPG files in the directory
        jpg_files = glob.glob(search_path)

        # Filter for files ending with retest.JPG and validation.JPG
        retest_files = [file for file in jpg_files if file.endswith("retest.JPG")]
        retrain_files = [file for file in jpg_files if file.endswith("retrain.JPG")]

        # Log file paths to check which files are being imported
        if retest_files:
            print(f" - Retest Image found: {retest_files[0]}")
        else:
            print("No Retest Image found.")
            print("ERROR --" * 50)

        if retrain_files:
            print(f" - retrain Image found: {retrain_files[0]}")
        else:
            print("No retrain Image found.")
            print("ERROR --" * 50)

        # **NEW** Search for files ending with retrain_distribution.JPG two sub-directories above the original path
        distribution_dir = os.path.abspath(os.path.join(path, "../.."))  # Two directories above
        distribution_search_path = os.path.join(distribution_dir, "*retrain_distribution.JPG")

        # Check if the retrain_distribution.JPG exists
        distribution_files = glob.glob(distribution_search_path)  # Search for the file

        if len(distribution_files) > 0:
            fig, ax = plt.subplots(figsize=(10, 8), dpi=150)  # Increase size and DPI for better quality
            retrain_distribution_img = mpimg.imread(distribution_files[0])
            ax.imshow(retrain_distribution_img)
            ax.set_title('retrain Distribution Plot', fontsize=16)  # Increased font size
            ax.axis('off')  # Turn off axis display
            plt.tight_layout()
            plt.show()

        # Plot the found JPG files (retest and retrain) side by side
        if retest_files or retrain_files:
            fig, axes = plt.subplots(1, 2, figsize=(12, 6), dpi=150)  # Larger figure and higher DPI

            # Load and display the retest image (if available)
            if retest_files:
                retest_img = mpimg.imread(retest_files[0])
                axes[0].imshow(retest_img)
                axes[0].set_title('Retest Image', fontsize=16)  # Increased font size
                axes[0].axis('off')  # Turn off axis display
            else:
                axes[0].axis('off')  # Leave the subplot blank if no image is available

            # Load and display the retrain image (if available)
            if retrain_files:
                retrain_img = mpimg.imread(retrain_files[0])
                axes[1].imshow(retrain_img)
                axes[1].set_title('retrain Image', fontsize=16)  # Increased font size
                axes[1].axis('off')  # Turn off axis display
            else:
                axes[1].axis('off')  # Leave the subplot blank if no image is available

            # Adjust layout and show the images
            plt.tight_layout(pad=2.0)  # Add padding between images
            plt.show()

            # Clear the figure from memory after displaying it
            plt.close()
            print("-" * 100)

        from IPython.display import display
        import pandas as pd
        
        # Assuming test_metrics and retrain_metrics are dictionaries with metric names as keys
        metrics_table = pd.DataFrame({
            'Metric': list(test_metrics.keys()),
            'Retest': list(test_metrics.values()),
            'Retrain': [retrain_metrics[metric.replace('(retest)', '(retrain)')] for metric in test_metrics.keys()]
        })
        
        # Display the table
        display(metrics_table)

        #print(metrics_table.to_string(index=False))
        print("=" * 100)

        # Print the relevant features
        print(f"Features Used: {row.features_retest}")
        print("-" * 100)

    print("exported to: ", r"C:\Users\robot\code\pipelines\apply_biomass\{0}_{1}_{2}_{3}_{4}_overall_best.csv".format(
        model_run, model, var, data, std))
    # Save the updated DataFrame to a CSV file
    
    return df, model_run, model, var, data, std

# %%
# Adjust filtering condition for R² if necessary
df_low_rmse = df_merged[(df_merged['rmse_retest'] <= 7000.0) & (df_merged['r2_retest'] >= 0.6)] #\
   #                     & (df_merged['rmse_test'] <= 12000.0) & (df_merged['r2_test'] >= 0.6)]  # Adjusted to 0.5 assuming typical R² values

# %%
#'rmse_retest', 'r2_retest', 'rmse_retrain', 'r2_retrain'

# %%
print(list(df_low_rmse))
# Out:
# ['r2_retrain', 'mse_retrain', 'rmse_retrain', 'mae_retrain', 'mape_retrain', 'bias_retrain', 'n_retrain', 'status_retrain', 'features_retrain', 'r2_retest', 'mse_retest', 'rmse_retest', 'mae_retest', 'mape_retest', 'bias_retest', 'n_retest', 'mdl', 'status_retest', 'var', 'fac', 'stdev', 'sel_num', 'data', 'stats', 'features_retest', 'model', 'file']

# %%
print(len(df_low_rmse))
# Out:
# 420

# %%
df_low_rmse
# Out:
#       r2_retrain  mse_retrain  rmse_retrain  mae_retrain  mape_retrain  \
# 43           NaN          NaN           NaN          NaN           NaN
# 76           NaN          NaN           NaN          NaN           NaN
# 82           NaN          NaN           NaN          NaN           NaN
# 88           NaN          NaN           NaN          NaN           NaN
# 122          NaN          NaN           NaN          NaN           NaN
# ...          ...          ...           ...          ...           ...
# 1603         NaN          NaN           NaN          NaN           NaN
# 1604         NaN          NaN           NaN          NaN           NaN
# 1615         NaN          NaN           NaN          NaN           NaN
# 1628         NaN          NaN           NaN          NaN           NaN
# 1652         NaN          NaN           NaN          NaN           NaN
#
#       bias_retrain  n_retrain status_retrain features_retrain    r2_retest  \
# 43             NaN        NaN            NaN              NaN 0.6000000000
# 76             NaN        NaN            NaN              NaN 0.6200000000
# 82             NaN        NaN            NaN              NaN 0.6300000000
# 88             NaN        NaN            NaN              NaN 0.6100000000
# 122            NaN        NaN            NaN              NaN 0.6500000000
# ...            ...        ...            ...              ...          ...
# 1603           NaN        NaN            NaN              NaN 0.6500000000
# 1604           NaN        NaN            NaN              NaN 0.6200000000
# 1615           NaN        NaN            NaN              NaN 0.6200000000
# 1628           NaN        NaN            NaN              NaN 0.6100000000
# 1652           NaN        NaN            NaN              NaN 0.6400000000
#
#       ...  status_retest         var   fac  stdev  sel_num  data stats  \
# 43    ...         retest  all03_rs30  RMSE      3       25  all0   p99
# 76    ...         retest  all03_rs30    r2      3       12  all0   p99
# 82    ...         retest  all03_rs30   MAE      3       12  all0   p99
# 88    ...         retest  all03_rs30  RMSE      3       12  all0   p99
# 122   ...         retest  all03_rs30    r2      3       20  all0   p99
# ...   ...            ...         ...   ...    ...      ...   ...   ...
# 1603  ...         retest  all01_rs30  RMSE      3       25  all0  mean
# 1604  ...         retest  all01_rs30  RMSE      3       20  all0  mean
# 1615  ...         retest  all01_rs30   MAE      3       25  all0   p99
# 1628  ...         retest  all01_rs30  RMSE      3       20  all0   p99
# 1652  ...         retest  all01_rs30  RMSE      3       20  all0  mean
#
#                                         features_retest  \
# 43    ['b1_wfp_dry_p99', 'b1_ccw_dry_p99', 'b1_hmc_p...
# 76    ['b1_hcv_p99', 'b2_dp1fm_dry_p99', 'b1_dp1fm_d...
# 82    ['b3_dp1fm_dry_p99', 'b1_h25_p99', 'b1_ccw_dry...
# 88    ['b1_dbifm_p99', 'b1_dp1fm_p99', 'b2_dbifm_p99...
# 122   ['b6_dbifm_p99', 'b1_hmc_p99', 'b2_dp1fm_p99',...
# ...                                                 ...
# 1603  ['b1_dp1fm_mean', 'b1_dp1fm_dry_mean', 'b2_dp1...
# 1604  ['dbifmdry_GNDVI', 'dbifmdry_MSR', 'dbifman_CV...
# 1615  ['b1_dp1fm_p99', 'b2_dbifm_p99', 'dbifmdry_RI'...
# 1628  ['b6_dbifm_p99', 'dbifmdry_GDVI', 'dbifmdry_NB...
# 1652  ['dbifmdry_GSAVI', 'dbifmdry_GNDVI', 'dbifman_...
#
#                                                   model  \
# 43                              RandomForestRegressor()
# 76    AdaBoostRegressor(estimator=DecisionTreeRegres...
# 82    AdaBoostRegressor(estimator=DecisionTreeRegres...
# 88    AdaBoostRegressor(estimator=DecisionTreeRegres...
# 122   GradientBoostingRegressor(learning_rate=0.05, ...
# ...                                                 ...
# 1603                              KNeighborsRegressor()
# 1604                              KNeighborsRegressor()
# 1615           KNeighborsRegressor(n_neighbors=10, p=1)
# 1628                              KNeighborsRegressor()
# 1652  XGBRegressor(base_score=None, booster=None, ca...
#
#                                                 file
# 43     all03_rs30_RMSE_RFR_sel_25_variable_score.csv
# 76       all03_rs30_r2_ABR_sel_12_variable_score.csv
# 82      all03_rs30_MAE_ABR_sel_12_variable_score.csv
# 88     all03_rs30_RMSE_ABR_sel_12_variable_score.csv
# 122      all03_rs30_r2_GBR_sel_20_variable_score.csv
# ...                                              ...
# 1603   all01_rs30_RMSE_KNN_sel_25_variable_score.csv
# 1604   all01_rs30_RMSE_KNN_sel_20_variable_score.csv
# 1615    all01_rs30_MAE_KNN_sel_25_variable_score.csv
# 1628   all01_rs30_RMSE_KNN_sel_20_variable_score.csv
# 1652  all01_rs30_RMSE_XGBR_sel_20_variable_score.csv
#
# [420 rows x 27 columns]

# %%
# Make a copy of the DataFrame
df_low_rmse_run = df_low_rmse.copy()
mdl_list = sorted(df_low_rmse_run.mdl.unique())
var_list = sorted(df_low_rmse_run["var"].unique())
data_list = sorted(df_low_rmse_run["data"].unique())
std_list = sorted(df_low_rmse_run["stdev"].unique())
#mdl = "GBR"
mdl_sel_df = df_low_rmse_run[df_low_rmse_run["var"]=='all01_rs30']
#mdl_sel_df = df_low_rmse_run[(df_low_rmse_run["var"]=='all01_rs30') & (df_low_rmse_run["mdl"]=='KNN')]
#mdl_sel_df = df_low_rmse_run[(df_low_rmse_run["var"]=='all01_rs0')&(df_low_rmse_run["data"]=='all0')&(df_low_rmse_run["mdl"]=='RFR')]
#mdl_sel_df = df[(df["mdl"]==mdl) & (df["data"]!="all_data") & ((df["var"]=="ann02_rs0") | (df["var"]=="ann02_rs47")) ]
#df = mdl_sel_df.copy()
#mdl_sel_df = df[df["mdl"]==mdl]
#dl_sel_df = df_low_rmse_run[df_low_rmse_run["data"]!= "all0"]
#mdl_sel_df = df_low_rmse_run
#mdl_sel_df.shape
print("mdl_list: ", mdl_list)
print(var_list)
print(data_list)
# Out:
# mdl_list:  ['ABR', 'GBR', 'KNN', 'RFR', 'XGBR']
# ['all01_rs30', 'all02_rs30', 'all03_rs30']
# ['all0']

# %%
best_df, model_run, model, var, data, std = plot_best_model(mdl_sel_df, model_run, "top", "top", "top", "top", 5)
# Out:
# Path: H:/biomass/model_model_all01_02_03_04_05_06_v2/AGB/all01_rs30/GBR/p99/std3/all0/r2/sel_num_20
# If using - create directory: all01_rs30_GBR_p99_std3_all0_r2_sel_num_20
# No Retest Image found.
# ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --
# No retrain Image found.
# ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --
#           Metric               Retest  Retrain
# 0    R² (retest)         0.8400000000      NaN
# 1   MSE (retest)   8697103.9199999999      NaN
# 2  RMSE (retest)      2949.0900000000      NaN
# 3   MAE (retest)      2138.9700000000      NaN
# 4  MAPE (retest) 837997907.3700000048      NaN
# 5  Bias (retest)      -588.9200000000      NaN
# 6     N (retest)        38.0000000000      NaN
# ====================================================================================================
# Features Used: ['b6_dbifm_p99', 'dbifmdry_NBR', 'b2_dp1fm_p99', 'b3_dp1fm_p99', 'dbifmdry_NDVI', 'b1_dp1fm_p99', 'dbifmdry_GSAVI', 'dbifman_NBR', 'dbifman_CVI', 'dbifmdry_GDVI', 'b1_dbifm_p99', 'b3_dp1fm_dry_p99', 'dbifman_MSR', 'dbifmdry_GNDVI', 'b2_dp1fm_dry_p99', 'b5_dbifm_p99', 'b3_dbifm_p99', 'dbifmdry_MSR', 'b2_dbifm_p99', 'dbifman_GNDVI']
# ----------------------------------------------------------------------------------------------------
# Path: H:/biomass/model_model_all01_02_03_04_05_06_v2/AGB/all01_rs30/GBR/p99/std3/all0/r2/sel_num_20
# If using - create directory: all01_rs30_GBR_p99_std3_all0_r2_sel_num_20
# No Retest Image found.
# ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --
# No retrain Image found.
# ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --
#           Metric               Retest  Retrain
# 0    R² (retest)         0.8400000000      NaN
# 1   MSE (retest)   8697103.9199999999      NaN
# 2  RMSE (retest)      2949.0900000000      NaN
# 3   MAE (retest)      2138.9700000000      NaN
# 4  MAPE (retest) 837997907.3700000048      NaN
# 5  Bias (retest)      -588.9200000000      NaN
# 6     N (retest)        38.0000000000      NaN
# ====================================================================================================
# Features Used: ['b6_dbifm_p99', 'dbifmdry_NBR', 'b2_dp1fm_p99', 'b3_dp1fm_p99', 'dbifmdry_NDVI', 'b1_dp1fm_p99', 'dbifmdry_GSAVI', 'dbifman_NBR', 'dbifman_CVI', 'dbifmdry_GDVI', 'b1_dbifm_p99', 'b3_dp1fm_dry_p99', 'dbifman_MSR', 'dbifmdry_GNDVI', 'b2_dp1fm_dry_p99', 'b5_dbifm_p99', 'b3_dbifm_p99', 'dbifmdry_MSR', 'b2_dbifm_p99', 'dbifman_GNDVI']
# ----------------------------------------------------------------------------------------------------
# Path: H:/biomass/model_model_all01_02_03_04_05_06_v2/AGB/all01_rs30/RFR/p99/std3/all0/RMSE/sel_num_15
# If using - create directory: all01_rs30_RFR_p99_std3_all0_RMSE_sel_num_15
# No Retest Image found.
# ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --
# No retrain Image found.
# ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --
#           Metric               Retest  Retrain
# 0    R² (retest)         0.8000000000      NaN
# 1   MSE (retest)  10726323.9700000007      NaN
# 2  RMSE (retest)      3275.1100000000      NaN
# 3   MAE (retest)      2294.9700000000      NaN
# 4  MAPE (retest) 928361246.3099999428      NaN
# 5  Bias (retest)      -826.8300000000      NaN
# 6     N (retest)        38.0000000000      NaN
# ====================================================================================================
# Features Used: ['b1_dbifm_p99', 'dbifmdry_NDVI', 'b5_dbifm_p99', 'b1_dp1fm_p99', 'dbifman_NDVI', 'b3_dp1fm_p99', 'dbifman_GNDVI', 'b3_dbifm_p99', 'b2_dp1fm_dry_p99', 'b2_dbifm_p99', 'b3_dp1fm_dry_p99', 'dbifman_MSR', 'b6_dbifm_p99', 'b2_dp1fm_p99', 'b1_dp1fm_dry_p99']
# ----------------------------------------------------------------------------------------------------
# Path: H:/biomass/model_model_all01_02_03_04_05_06_v2/AGB/all01_rs30/RFR/p99/std3/all0/RMSE/sel_num_15
# If using - create directory: all01_rs30_RFR_p99_std3_all0_RMSE_sel_num_15
# No Retest Image found.
# ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --
# No retrain Image found.
# ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --
#           Metric               Retest  Retrain
# 0    R² (retest)         0.8000000000      NaN
# 1   MSE (retest)  10726323.9700000007      NaN
# 2  RMSE (retest)      3275.1100000000      NaN
# 3   MAE (retest)      2294.9700000000      NaN
# 4  MAPE (retest) 928361246.3099999428      NaN
# 5  Bias (retest)      -826.8300000000      NaN
# 6     N (retest)        38.0000000000      NaN
# ====================================================================================================
# Features Used: ['b1_dbifm_p99', 'dbifmdry_NDVI', 'b5_dbifm_p99', 'b1_dp1fm_p99', 'dbifman_NDVI', 'b3_dp1fm_p99', 'dbifman_GNDVI', 'b3_dbifm_p99', 'b2_dp1fm_dry_p99', 'b2_dbifm_p99', 'b3_dp1fm_dry_p99', 'dbifman_MSR', 'b6_dbifm_p99', 'b2_dp1fm_p99', 'b1_dp1fm_dry_p99']
# ----------------------------------------------------------------------------------------------------
# Path: H:/biomass/model_model_all01_02_03_04_05_06_v2/AGB/all01_rs30/ABR/p99/std3/all0/RMSE/sel_num_25
# If using - create directory: all01_rs30_ABR_p99_std3_all0_RMSE_sel_num_25
# No Retest Image found.
# ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --
# No retrain Image found.
# ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --ERROR --
#           Metric               Retest  Retrain
# 0    R² (retest)         0.8000000000      NaN
# 1   MSE (retest)  10822001.3300000001      NaN
# 2  RMSE (retest)      3289.6800000000      NaN
# 3   MAE (retest)      2314.8700000000      NaN
# 4  MAPE (retest) 721297898.2799999714      NaN
# 5  Bias (retest)      -355.2600000000      NaN
# 6     N (retest)        38.0000000000      NaN
# ====================================================================================================
# Features Used: ['b2_dp1fm_p99', 'b1_dp1fm_p99', 'b1_dp1fm_dry_p99', 'b3_dp1fm_p99', 'b2_dp1fm_dry_p99', 'b3_dp1fm_dry_p99', 'b1_dbifm_p99', 'b5_dbifm_p99', 'b3_dbifm_p99', 'b6_dbifm_p99', 'b2_dbifm_p99', 'dbifmdry_GSAVI', 'dbifman_r42', 'dbifmdry_GNDVI', 'dbifmdry_NDGI', 'dbifmdry_NBR', 'dbifman_NDGI', 'dbifman_GNDVI', 'dbifman_MSR', 'b4_dbifm_p99', 'dbifmdry_MSR', 'dbifmdry_CVI', 'dbifmdry_RI', 'dbifman_NBR', 'dbifman_CVI']
# ----------------------------------------------------------------------------------------------------
# Display limit reached. Adjust the display limit to see more images.
# exported to:  C:\Users\robot\code\pipelines\apply_biomass\model_all01_02_03_04_05_06_v2_top_top_top_top_overall_best.csv

# %%
best_df.to_csv(r"C:\Users\robot\code\pipelines\apply_biomass\{0}_{1}_{2}_{3}_{4}_rs30_all03_overall_best.csv".format(model_run, model, var, data, std))
print(r"C:\Users\robot\code\pipelines\apply_biomass\{0}_{1}_{2}_{3}_{4}_rs30_all03_overall_best.csv".format(model_run, model, var, data, std))
# Out:
# C:\Users\robot\code\pipelines\apply_biomass\model_all01_02_03_04_05_06_v2_top_top_top_top_rs30_all03_overall_best.csv

# %%
best_df
# Out:
#       r2_retrain  mse_retrain  rmse_retrain  mae_retrain  mape_retrain  \
# 698          NaN          NaN           NaN          NaN           NaN
# 1562         NaN          NaN           NaN          NaN           NaN
# 1479         NaN          NaN           NaN          NaN           NaN
# 615          NaN          NaN           NaN          NaN           NaN
# 1525         NaN          NaN           NaN          NaN           NaN
# ...          ...          ...           ...          ...           ...
# 0            NaN          NaN           NaN          NaN           NaN
# 1            NaN          NaN           NaN          NaN           NaN
# 2            NaN          NaN           NaN          NaN           NaN
# 3            NaN          NaN           NaN          NaN           NaN
# 4            NaN          NaN           NaN          NaN           NaN
#
#       bias_retrain  n_retrain status_retrain features_retrain    r2_retest  \
# 698            NaN        NaN            NaN              NaN 0.8400000000
# 1562           NaN        NaN            NaN              NaN 0.8400000000
# 1479           NaN        NaN            NaN              NaN 0.8000000000
# 615            NaN        NaN            NaN              NaN 0.8000000000
# 1525           NaN        NaN            NaN              NaN 0.8000000000
# ...            ...        ...            ...              ...          ...
# 0              NaN        NaN            NaN              NaN          NaN
# 1              NaN        NaN            NaN              NaN          NaN
# 2              NaN        NaN            NaN              NaN          NaN
# 3              NaN        NaN            NaN              NaN          NaN
# 4              NaN        NaN            NaN              NaN          NaN
#
#       ...   fac        stdev       sel_num  data  stats  \
# 698   ...    r2 3.0000000000 20.0000000000  all0    p99
# 1562  ...    r2 3.0000000000 20.0000000000  all0    p99
# 1479  ...  RMSE 3.0000000000 15.0000000000  all0    p99
# 615   ...  RMSE 3.0000000000 15.0000000000  all0    p99
# 1525  ...  RMSE 3.0000000000 25.0000000000  all0    p99
# ...   ...   ...          ...           ...   ...    ...
# 0     ...   NaN          NaN           NaN   NaN    NaN
# 1     ...   NaN          NaN           NaN   NaN    NaN
# 2     ...   NaN          NaN           NaN   NaN    NaN
# 3     ...   NaN          NaN           NaN   NaN    NaN
# 4     ...   NaN          NaN           NaN   NaN    NaN
#
#                                         features_retest  \
# 698   ['b6_dbifm_p99', 'dbifmdry_NBR', 'b2_dp1fm_p99...
# 1562  ['b6_dbifm_p99', 'dbifmdry_NBR', 'b2_dp1fm_p99...
# 1479  ['b1_dbifm_p99', 'dbifmdry_NDVI', 'b5_dbifm_p9...
# 615   ['b1_dbifm_p99', 'dbifmdry_NDVI', 'b5_dbifm_p9...
# 1525  ['b2_dp1fm_p99', 'b1_dp1fm_p99', 'b1_dp1fm_dry...
# ...                                                 ...
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#
#                                                   model  \
# 698   GradientBoostingRegressor(max_features='sqrt',...
# 1562  GradientBoostingRegressor(max_features='sqrt',...
# 1479  RandomForestRegressor(max_depth=3, max_feature...
# 615   RandomForestRegressor(max_depth=3, max_feature...
# 1525  AdaBoostRegressor(estimator=DecisionTreeRegres...
# ...                                                 ...
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#
#                                                file  \
# 698     all01_rs30_r2_GBR_sel_20_variable_score.csv
# 1562    all01_rs30_r2_GBR_sel_20_variable_score.csv
# 1479  all01_rs30_RMSE_RFR_sel_15_variable_score.csv
# 615   all01_rs30_RMSE_RFR_sel_15_variable_score.csv
# 1525  all01_rs30_RMSE_ABR_sel_25_variable_score.csv
# ...                                             ...
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#                                               file_path  \
# 698   H:/biomass/model_model_all01_02_03_04_05_06_v2...
# 1562  H:/biomass/model_model_all01_02_03_04_05_06_v2...
# 1479  H:/biomass/model_model_all01_02_03_04_05_06_v2...
# 615   H:/biomass/model_model_all01_02_03_04_05_06_v2...
# 1525  H:/biomass/model_model_all01_02_03_04_05_06_v2...
# ...                                                 ...
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#
#                                          apply_mdl
# 698                                            NaN
# 1562                                           NaN
# 1479                                           NaN
# 615                                            NaN
# 1525                                           NaN
# ...                                            ...
# 0       all01_rs30_GBR_p99_std3_all0_r2_sel_num_20
# 1       all01_rs30_GBR_p99_std3_all0_r2_sel_num_20
# 2     all01_rs30_RFR_p99_std3_all0_RMSE_sel_num_15
# 3     all01_rs30_RFR_p99_std3_all0_RMSE_sel_num_15
# 4     all01_rs30_ABR_p99_std3_all0_RMSE_sel_num_25
#
# [163 rows x 29 columns]

# %%
best_df

# %%
# Find the model with the lowest RMSE
best_perform_model = best_df.loc[best_df['rmse_retest'].idxmin()]

# Calculate summary statistics
summary_stats = best_df.describe()

# Output results
print("Summary Statistics:")
print(summary_stats)
print("\nModel with the Lowest RMSE:")
print(best_perform_model)

# %%
# Normalise metrics
best_df['RMSE_norm'] = best_df['rmse_retest'] / best_df['rmse_retest'].max()  # Lower is better
best_df['MAE_norm'] = best_df['mae_retest'] / best_df['mae_retest'].max()    # Lower is better
best_df['R2_norm'] = 1 - ((best_df['r2_retest'].max() - best_df['r2_retest']) / (best_df['r2_retest'].max() - best_df['r2_retest'].min()))  # Higher is better

# Assign weights to each metric (optional)
weights = {'rmse_retest': 0.8, 'mae_retest': 0.1, 'r2_retest': 0.1}

# Calculate combined score
best_df['Score'] = (
    best_df['RMSE_norm'] * weights['rmse_retest'] +
    best_df['MAE_norm'] * weights['mae_retest'] +
    best_df['R2_norm'] * weights['r2_retest']
)

# Rank models based on the score
best_df['Rank'] = best_df['Score'].rank(ascending=True)

# Sort by rank
df_rank = best_df.sort_values(by='Rank')

# Output results
df_rank[['mdl', 'rmse_retest', 'mae_retest', 'r2_retest', 'Score', 'Rank', 'file_path', 'model', 'features_retest']]

# %%
# Group by 'mdl' and get the best rank (minimum score) per model
best_rank_per_model = df_rank.groupby('mdl', as_index=False).first()

# Sort the models by Rank for clear display
best_rank_per_model = best_rank_per_model.sort_values(by='Rank')

# Output the results
print("Best Rank for Each Model:")
best_rank_per_model[['mdl', 'rmse_retest', 'mae_retest', 'r2_retest', 'Score', 'Rank', 'file_path', 'model', 'features_retest']]

# %%
# Group by 'mdl' and find the row with the minimum 'rmse_retest' for each model
lowest_rmse_df = best_df.loc[best_df.groupby('mdl')['rmse_retest'].idxmin()]
# Reset index for cleaner presentation
lowest_rmse_df = lowest_rmse_df.reset_index(drop=True)

# Display the table with the lowest RMSE per model
print("Table of Lowest RMSE for Each Model:")
lowest_rmse_df

# %%
best_rank_per_model.to_csv(r"C:\Users\robot\code\pipelines\apply_biomass\{0}_{1}_{2}_{3}_{4}_AGB_best_model_results_rs30_all03.csv".format(model_run, model, var, data, std))
#best_rank_per_model.to_csv(r"H:\biomass\model_test_train_all01_02_03_04_05_06_final\AGB_best_model_results_rs30_all03.csv", index=False)
print(r"C:\Users\robot\code\pipelines\apply_biomass\{0}_{1}_{2}_{3}_{4}_AGB_best_model_results_rs30_all03.csv".format(model_run, model, var, data, std))

# %%
grouped_df = best_df.groupby(['mdl'])[['rmse_retest', 'r2_retest', 'mae_retest']].agg(['mean', 'std']).reset_index()
grouped_df

# %%
best_df
